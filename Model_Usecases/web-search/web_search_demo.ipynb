# %% [markdown]
# # Web Search quickstart
#
# Demonstrates Azure OpenAI Responses API with the `web_search_preview` tool using environment variables loaded via `.env`.

# %% [markdown]
# ## Prerequisites
# - Install `openai` (>=1.56.0) and `python-dotenv`.
# - Populate `.env` with your Azure OpenAI settings. Supported keys (first match wins):
#   - Base URL: `AZURE_OPENAI_BASE_URL` | `AZURE_OPENAI_API_BASE` | `AZURE_EXISTING_AIPROJECT_ENDPOINT`
#   - API key: `AZURE_OPENAI_API_KEY` | `OPENAI_API_KEY`
#   - Model deployment (optional): `AZURE_OPENAI_MODEL` | `AZURE_OPENAI_DEPLOYMENT` (default `gpt-4.1`)
#   - Country code (optional): `AZURE_OPENAI_COUNTRY` (for location-biased search)
#   - Deep research deployment (optional): `AZURE_OPENAI_DEEP_MODEL`
# - Using web search can incur costs and sends data to Bing for grounding.

# %%
# If needed, install dependencies (uncomment to run)
# %pip install -U openai python-dotenv

# %%
import os
from dotenv import load_dotenv

load_dotenv(override=True)

base_url = (
    os.getenv("AZURE_OPENAI_BASE_URL")
    or os.getenv("AZURE_OPENAI_API_BASE")
    or os.getenv("AZURE_EXISTING_AIPROJECT_ENDPOINT")
)
api_key = os.getenv("AZURE_OPENAI_API_KEY") or os.getenv("OPENAI_API_KEY")
model = os.getenv("AZURE_OPENAI_MODEL") or os.getenv("AZURE_OPENAI_DEPLOYMENT") or "gpt-4.1-mini"
print(model)
country = os.getenv("AZURE_OPENAI_COUNTRY")
deep_model = os.getenv("AZURE_OPENAI_DEEP_MODEL")
print(deep_model)

if not base_url or not api_key:
    raise ValueError("Set base URL and API key in .env (see prerequisites).")

base_url = base_url.rstrip("/")
if not base_url.endswith("/openai/v1"):
    base_url = f"{base_url}/openai/v1"
# Out:
# gpt-4.1-mini
# o3-pro

# %%
from openai import OpenAI

client = OpenAI(api_key=api_key, base_url=base_url)
print(f"Client ready against {base_url}")
# Out:
# Client ready against https://eu2-oai.openai.azure.com/openai/v1

# %%
#Formatting code
import json
from typing import Optional, List

def run_search(prompt: str, tools: List[dict], model_override: Optional[str] = None):
    response = client.responses.create(
        model=model_override or model,
        tools=tools,
        input=prompt,
    )

    print(response.output_text)

    # Display annotations (citations) if present
    messages = [item for item in response.output or [] if item.type == "message"]
    for message in messages:
        for content in message.content or []:
            if hasattr(content, 'annotations') and content.annotations:
                print("\n" + "=" * 80)
                print("Citations:")
                print("=" * 80)
                for i, annotation in enumerate(content.annotations, 1):
                    # Extract the cited text using start_index and end_index
                    if hasattr(annotation, 'start_index') and hasattr(annotation, 'end_index'):
                        cited_text = content.text[annotation.start_index:annotation.end_index]
                        print(f"\n[{i}] {cited_text}")
                    else:
                        print(f"\n[{i}] Citation {i}")
                    
                    # Display URL and title if available
                    if hasattr(annotation, 'url') and annotation.url:
                        print(f"    URL: {annotation.url}")
                    if hasattr(annotation, 'title') and annotation.title:
                        print(f"    Title: {annotation.title}")
                print("=" * 80)

    actions = [item for item in response.output or [] if item.type == "web_search_call"]
    if actions:
        print("\n" + "=" * 80)
        print("Tool calls:")
        print("=" * 80)
        for i, action in enumerate(actions, 1):
            try:
                print(f"\nCall {i}:")
                print(json.dumps(action.model_dump(), indent=2, ensure_ascii=False, sort_keys=False))
            except Exception:
                print(action)
        print("=" * 80)

    return response

# %% [markdown]
# ### Quick lookup (single search)
# Uses the fastest path: the model forwards the prompt directly to web search without multi-step planning.

# %%
run_search(
    "What happened in the last NFL game?",
    tools=[{"type": "web_search_preview"}],
)
# Out:
# The last NFL game was the Wild Card playoff between the Los Angeles Rams and the Carolina Panthers, where the Rams won 34-31. This game occurred on January 10, 2026. There were other recent playoff games as well, including the Bears beating the Packers 31-27 and the Bills winning against the Jaguars 27-24.
#
# For the latest ongoing games in the Divisional Round playoffs:
# - Buffalo Bills vs. Denver Broncos on January 17, 2026
# - San Francisco 49ers vs. Seattle Seahawks on January 17, 2026
# - Houston Texans vs. New England Patriots on January 18, 2026
# - Los Angeles Rams vs. Chicago Bears on January 18, 2026
#
# If you want details on a specific recent game or ongoing one, let me know!
#
# Source: [CBSSports NFL Scores](https://www.cbssports.com/nfl/scoreboard/all/)
#
# ================================================================================
# Citations:
# ================================================================================
#
# [1] [CBSSports NFL Scores](https://www.cbssports.com/nfl/scoreboard/all/)
#     URL: https://www.cbssports.com/nfl/scoreboard/all/
#     Title: NFL Game Scores - - CBS Sports
# ================================================================================
#
# ================================================================================
# Tool calls:
# ================================================================================
#
# Call 1:
# {
#   "id": "ws_041f129d557177e10069694e40e5b881908bceb0c06c067905",
#   "action": {
#     "query": "latest NFL game results",
#     "type": "search",
#     "sources": null
#   },
#   "status": "searching",
#   "type": "web_search_call"
# }
# ================================================================================
# Response(id='resp_041f129d557177e10069694e3faa708190ae74fd94f595c6f5', created_at=1768508991.0, error=None, incomplete_details=None, instructions=None, metadata={}, model='gpt-4.1-mini', object='response', output=[ResponseFunctionWebSearch(id='ws_041f129d557177e10069694e40e5b881908bceb0c06c067905', action=ActionSearch(query='latest NFL game results', type='search', sources=None), status='searching', type='web_search_call'), ResponseOutputMessage(id='msg_041f129d557177e10069694e41c6c88190a803db0bda2858a6', content=[ResponseOutputText(annotations=[AnnotationURLCitation(end_index=764, start_index=695, title='NFL Game Scores - - CBS Sports', type='url_citation', url='https://www.cbssports.com/nfl/scoreboard/all/')], text='The last NFL game was the Wild Card playoff between the Los Angeles Rams and the Carolina Panthers, where the Rams won 34-31. This game occurred on January 10, 2026. There were other recent playoff games as well, including the Bears beating the Packers 31-27 and the Bills winning against the Jaguars 27-24.\n\nFor the latest ongoing games in the Divisional Round playoffs:\n- Buffalo Bills vs. Denver Broncos on January 17, 2026\n- San Francisco 49ers vs. Seattle Seahawks on January 17, 2026\n- Houston Texans vs. New England Patriots on January 18, 2026\n- Los Angeles Rams vs. Chicago Bears on January 18, 2026\n\nIf you want details on a specific recent game or ongoing one, let me know! \n\nSource: [CBSSports NFL Scores](https://www.cbssports.com/nfl/scoreboard/all/)', type='output_text', logprobs=[])], role='assistant', status='completed', type='message')], parallel_tool_calls=True, temperature=1.0, tool_choice='auto', tools=[WebSearchPreviewTool(type='web_search_preview', search_context_size='medium', user_location=UserLocation(type='approximate', city=None, country='US', region=None, timezone=None))], top_p=1.0, background=False, conversation=None, max_output_tokens=None, max_tool_calls=None, previous_response_id=None, prompt=None, prompt_cache_key=None, reasoning=Reasoning(effort=None, generate_summary=None, summary=None), safety_identifier=None, service_tier='default', status='completed', text=ResponseTextConfig(format=ResponseFormatText(type='text'), verbosity='medium'), top_logprobs=0, truncation='disabled', usage=ResponseUsage(input_tokens=5727, input_tokens_details=InputTokensDetails(cached_tokens=0), output_tokens=210, output_tokens_details=OutputTokensDetails(reasoning_tokens=0), total_tokens=5937), user=None, content_filters=[{'blocked': False, 'source_type': 'prompt', 'content_filter_raw': None, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'jailbreak': {'filtered': False, 'detected': False}, 'violence': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}}, 'content_filter_offsets': {'start_offset': 1836, 'end_offset': 1871, 'check_offset': 0}}, {'blocked': False, 'source_type': 'completion', 'content_filter_raw': None, 'content_filter_results': {'violence': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'hate': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'protected_material_text': {'filtered': False, 'detected': False}, 'protected_material_code': {'filtered': False, 'detected': False}}, 'content_filter_offsets': {'start_offset': 0, 'end_offset': 21469, 'check_offset': 0}}], prompt_cache_retention=None, store=True)

# %%
run_search(
    "What happened in the last NFL game?",
    tools=[{"type": "web_search_preview"}],
)
# Out:
# In the Verona vs Bologna match on January 15, 2026, Bologna won with a score of 3-1.
#
# - Gift Orban scored first for Verona in the 13th minute.
# - Riccardo Orsolini equalized for Bologna at the 21st minute.
# - Jens Odgaard then put Bologna ahead with a goal in the 29th minute.
# - Santiago Castro sealed the victory for Bologna in the 44th minute.
#
# The match took place at Stadio Marc'Antonio Bentegodi in Verona. Verona had 38% ball possession and Bologna 62%. The game was part of the Serie A league.
#
# Referee: Maurizio Mariani
#
# This result means Bologna secured a win away from home against Verona with a 3-1 scoreline.[Sky Sports](https://www.skysports.com/football/verona-vs-bologna/live/530208), [ESPN](https://www.espn.com/football/match/_/gameId/736941), [Soccerway](https://us.soccerway.com/game/bologna-0M9xNN8N/verona-rJVAIaHo/)
#
# ================================================================================
# Citations:
# ================================================================================
#
# [1] [Sky Sports](https://www.skysports.com/football/verona-vs-bologna/live/530208)
#     URL: https://www.skysports.com/football/verona-vs-bologna/live/530208
#     Title: Verona vs Bologna - Live match updates | 15.01.2026 - Sky Sports
#
# [2] [ESPN](https://www.espn.com/football/match/_/gameId/736941)
#     URL: https://www.espn.com/football/match/_/gameId/736941
#     Title: Verona vs. Bologna (Jan 15, 2026) Live Score - ESPN
#
# [3] [Soccerway](https://us.soccerway.com/game/bologna-0M9xNN8N/verona-rJVAIaHo/)
#     URL: https://us.soccerway.com/game/bologna-0M9xNN8N/verona-rJVAIaHo/
#     Title: Verona v Bologna live scores & match info | Soccerway
# ================================================================================
#
# ================================================================================
# Tool calls:
# ================================================================================
#
# Call 1:
# {
#   "id": "ws_0693eb11a506a1970069694d17c3ec8195a570415de95e7591",
#   "action": {
#     "query": "Verona vs Bologna latest match result",
#     "type": "search",
#     "sources": null
#   },
#   "status": "searching",
#   "type": "web_search_call"
# }
# ================================================================================
# Response(id='resp_0693eb11a506a1970069694d178ac08195ad65d442e9a02ec8', created_at=1768508695.0, error=None, incomplete_details=None, instructions=None, metadata={}, model='gpt-4.1-mini', object='response', output=[ResponseFunctionWebSearch(id='ws_0693eb11a506a1970069694d17c3ec8195a570415de95e7591', action=ActionSearch(query='Verona vs Bologna latest match result', type='search', sources=None), status='searching', type='web_search_call'), ResponseOutputMessage(id='msg_0693eb11a506a1970069694d1895cc8195893558930aebeb23', content=[ResponseOutputText(annotations=[AnnotationURLCitation(end_index=697, start_index=619, title='Verona vs Bologna - Live match updates | 15.01.2026 - Sky Sports', type='url_citation', url='https://www.skysports.com/football/verona-vs-bologna/live/530208'), AnnotationURLCitation(end_index=758, start_index=699, title='Verona vs. Bologna (Jan 15, 2026) Live Score - ESPN', type='url_citation', url='https://www.espn.com/football/match/_/gameId/736941'), AnnotationURLCitation(end_index=836, start_index=760, title='Verona v Bologna live scores & match info | Soccerway', type='url_citation', url='https://us.soccerway.com/game/bologna-0M9xNN8N/verona-rJVAIaHo/')], text="In the Verona vs Bologna match on January 15, 2026, Bologna won with a score of 3-1. \n\n- Gift Orban scored first for Verona in the 13th minute.\n- Riccardo Orsolini equalized for Bologna at the 21st minute.\n- Jens Odgaard then put Bologna ahead with a goal in the 29th minute.\n- Santiago Castro sealed the victory for Bologna in the 44th minute.\n\nThe match took place at Stadio Marc'Antonio Bentegodi in Verona. Verona had 38% ball possession and Bologna 62%. The game was part of the Serie A league.\n\nReferee: Maurizio Mariani\n\nThis result means Bologna secured a win away from home against Verona with a 3-1 scoreline.[Sky Sports](https://www.skysports.com/football/verona-vs-bologna/live/530208), [ESPN](https://www.espn.com/football/match/_/gameId/736941), [Soccerway](https://us.soccerway.com/game/bologna-0M9xNN8N/verona-rJVAIaHo/)", type='output_text', logprobs=[])], role='assistant', status='completed', type='message')], parallel_tool_calls=True, temperature=1.0, tool_choice='auto', tools=[WebSearchPreviewTool(type='web_search_preview', search_context_size='medium', user_location=UserLocation(type='approximate', city=None, country='US', region=None, timezone=None))], top_p=1.0, background=False, conversation=None, max_output_tokens=None, max_tool_calls=None, previous_response_id=None, prompt=None, prompt_cache_key=None, reasoning=Reasoning(effort=None, generate_summary=None, summary=None), safety_identifier=None, service_tier='default', status='completed', text=ResponseTextConfig(format=ResponseFormatText(type='text'), verbosity='medium'), top_logprobs=0, truncation='disabled', usage=ResponseUsage(input_tokens=8886, input_tokens_details=InputTokensDetails(cached_tokens=0), output_tokens=258, output_tokens_details=OutputTokensDetails(reasoning_tokens=0), total_tokens=9144), user=None, content_filters=[{'blocked': False, 'source_type': 'prompt', 'content_filter_raw': None, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'jailbreak': {'filtered': False, 'detected': False}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}, 'content_filter_offsets': {'start_offset': 1836, 'end_offset': 1881, 'check_offset': 0}}, {'blocked': False, 'source_type': 'completion', 'content_filter_raw': None, 'content_filter_results': {'violence': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'hate': {'filtered': False, 'severity': 'safe'}, 'protected_material_text': {'filtered': False, 'detected': False}, 'protected_material_code': {'filtered': False, 'detected': False}}, 'content_filter_offsets': {'start_offset': 0, 'end_offset': 29323, ...

# %%
run_search(
    "What are the top 5 renewable energy trends in 2026, and which companies are leading in solar and wind adoption globally?",
    tools=[{"type": "web_search_preview"}],
)
# Out:
# The top 5 renewable energy trends in 2026 are:
#
# 1. **Energy Storage Breakthroughs:** Wider use of advanced batteries like lithium-silicon and sodium-ion, and more grid-scale and long-duration energy storage (LDES) to ensure 24/7 clean energy supply.
#
# 2. **Solar Power Innovations:** Commercialization of perovskite solar cells for higher efficiency at lower cost, growth in floating solar farms especially in Asia and Europe, and more integration of solar materials into buildings (Building-Integrated Photovoltaics, BIPV).
#
# 3. **Green Hydrogen Expansion:** More national hydrogen strategies, reduced electrolyzer costs, and hydrogen hubs in Europe, Asia, and the Middle East enabling decarbonization of hard-to-abate sectors.
#
# 4. **Offshore Wind Growth:** Major projects in the North Sea, U.S. East Coast, and Asia-Pacific; growth in floating offshore wind technology for deeper waters; and hybrid systems combining wind with hydrogen or solar.
#
# 5. **Smart Grids and AI Integration:** Digital transformation with AI and IoT for smart grids, blockchain-powered decentralized energy markets, and advanced predictive analytics for grid management.
#
# Leading companies in solar and wind adoption globally include:
#
# - **Solar:** China dominates the manufacturing and adoption landscape, with companies like LONGi and JinkoSolar leading in solar panel production and installations. The U.S. and Europe have strong solar developers focusing on integrating solar into urban infrastructure.
#
# - **Wind:** Companies like Ørsted (Denmark), Vestas (Denmark), Siemens Gamesa (Spain/Germany), and General Electric (U.S.) lead in offshore and onshore wind project development. China’s Goldwind also leads among turbine manufacturers and has large wind farms.
#
# China is the overall leader in clean energy investment and deployment, followed by the U.S. and European countries, which are also advancing grid modernization and renewable integration aggressively.
#
# Sources:
# - Renewable Energy Trends 2026, Renewable Energy Conference Blog: [renewableenergyconference.org](https://www.renewableenergyconference.org/blog/trends-in-renewable-energy-2026.html)
# - Deloitte 2026 Renewable Energy Industry Outlook: [pv-magazine-usa.com](https://pv-magazine-usa.com/2025/10/30/five-trends-that-will-shape-renewable-energy-in-2026/)
# - World Economic Forum Global Energy 2026: [weforum.org](https://www.weforum.org/stories/2025/12/global-energy-2026-growth-resilience-and-competition/)
# - Energy Evolution Conference Global Trends: [energyevolutionconference.com](https://energyevolutionconference.com/the-future-of-renewable-energy-global-trends-and-predictions-for-2026-and-beyond/)
#
# ================================================================================
# Citations:
# ================================================================================
#
# [1] [renewableenergyconference.org](https://www.renewableenergyconference.org/blog/trends-in-renewable-energy-2026.html)
#     URL: https://www.renewableenergyconference.org/blog/trends-in-renewable-energy-2026.html
#     Title: What Are the Top Trends in Renewable Energy for 2026?
#
# [2] [pv-magazine-usa.com](https://pv-magazine-usa.com/2025/10/30/five-trends-that-will-shape-renewable-energy-in-2026/)
#     URL: https://pv-magazine-usa.com/2025/10/30/five-trends-that-will-shape-renewable-energy-in-2026/
#     Title: Five trends that will shape renewable energy in 2026
#
# [3] [energyevolutionconference.com](https://energyevolutionconference.com/the-future-of-renewable-energy-global-trends-and-predictions-for-2026-and-beyond/)
#     URL: https://energyevolutionconference.com/the-future-of-renewable-energy-global-trends-and-predictions-for-2026-and-beyond/
#     Title: The Future of Renewable Energy: Global Trends and Predictions for 2026 ...
#
# [4] [weforum.org](https://www.weforum.org/stories/2025/12/global-energy-2026-growth-resilience-and-competition/)
#     URL: https://www.weforum.org/stories/2025/12/global-energy-2026-growth-resilience-and-competition/
#     Title: Global energy in 2026: Growth, resilience and competition
# ================================================================================
#
# ================================================================================
# Tool calls:
# ================================================================================
#
# Call 1:
# {
#   "id": "ws_0d0f8ef081c7d46400696940880414819587ccad29ee15b744",
#   "action": {
#     "query": "top renewable energy trends 2026",
#     "type": "search",
#     "sources": null
#   },
#   "status": "searching",
#   "type": "web_search_call"
# }
# ================================================================================
# Response(id='resp_0d0f8ef081c7d4640069694087c2fc8195ba36f0547fc2d5cd', created_at=1768505479.0, error=None, incomplete_details=None, instructions=None, metadata={}, model='gpt-4.1-mini', object='response', output=[ResponseFunctionWebSearch(id='ws_0d0f8ef081c7d46400696940880414819587ccad29ee15b744', action=ActionSearch(query='top renewable energy trends 2026', type='search', sources=None), status='searching', type='web_search_call'), ResponseOutputMessage(id='msg_0d0f8ef081c7d4640069694089dcb8819583c83fa7994c1b77', content=[ResponseOutputText(annotations=[AnnotationURLCitation(end_index=2138, start_index=2022, title='What Are the Top Trends in Renewable Energy for 2026?', type='url_citation', url='https://www.renewableenergyconference.org/blog/trends-in-renewable-energy-2026.html'), AnnotationURLCitation(end_index=2307, start_index=2192, title='Five trends that will shape renewable energy in 2026', type='url_citation', url='https://pv-magazine-usa.com/2025/10/30/five-trends-that-will-shape-renewable-energy-in-2026/'), AnnotationURLCitation(end_index=2661, start_index=2509, title='The Future of Renewable Energy: Global Trends and Predictions for 2026 ...', type='url_citation', url='https://energyevolutionconference.com/the-future-of-renewable-energy-global-trends-and-predictions-for-2026-and-beyond/'), AnnotationURLCitation(end_index=2461, start_index=2353, title='Global energy in 2026: Growth, resilience and competition', type='url_citation', url='https://www.weforum.org/stories/2025/12/global-energy-2026-growth-resilience-and-competition/')], text='The top 5 renewable energy trends in 2026 are:\n\n1. **Energy Storage Breakthroughs:** Wider use of advanced batteries like lithium-silicon and sodium-ion, and more grid-scale and long-duration energy storage (LDES) to ensure 24/7 clean energy supply.\n\n2. **Solar Power Innovations:** Commercialization of perovskite solar cells for higher efficiency at lower cost, growth in floating solar farms especially in Asia and Europe, and more integration of solar materials into buildings (Building-Integrated Photovoltaics, BIPV).\n\n3. **Green Hydrogen Expansion:** More national hydrogen strategies, reduced electrolyzer costs, and hydrogen hubs in Europe, Asia, and the Middle East enabling decarbonization of hard-to-abate sectors.\n\n4. **Offshore Wind Growth:** Major projects in the North Sea, U.S. East Coast, and Asia-Pacific; growth in floating offshore wind technology for deeper waters; and hybrid systems combining wind with hydrogen or solar.\n\n5. **Smart Grids and AI Integration:** Digital transformation with AI and IoT for smart grids, blockchain-powered decentralized energy markets, and advanced predictive analytics for grid management.\n\nLeading companies in solar and wind adoption globally include:\n\n- **Solar:** China dominates the manufacturing and adoption landscape, with companies like LONGi and JinkoSolar leading in solar panel production and installations. The U.S. and Europe have strong solar developers focusing on integrating solar into urban infrastructure.\n\n- **Wind:** Companies like Ørsted (Denmark), Vestas (Denmark), Siemens Gamesa (Spain/Germany), and General Electric (U.S.) lead in offshore and onshore wind project development. China’s Goldwind also leads among turbine manufacturers and has large wind farms.\n\nChina is the overall leader in clean energy investment and deployment, followed by the U.S. and European countries, which are also advancing grid modernization and renewable integration aggressively.\n\nSources:  \n- Renewable Energy Trends 2026, Renewable Energy Conference Blog: [renewableenergyconference.org](https://www.renewableenergyconference.org/blog/trends-in-renewable-energy-2026.html)  \n- Deloitte 2026 Renewable Energy Industry Outlook: [pv-magazine-usa.com](https://pv-magazine-usa.com/2025/10/30/five-trends-that-will-shape-renewable-energy-in-2026/)  \n- World Economic Forum Global Energy 2026: [weforum.org](https://www.weforum.org/stories/202 ...

# %%
run_search(
    "What are the top 5 renewable energy trends in 2026, and which companies are leading in solar and wind adoption globally?",
    tools=[{"type": "web_search_preview"}],
)
# Out:
# ## Top 5 renewable energy trends shaping **2026**
# 1. **Hybrid renewables (solar/wind + batteries) becoming the default**
#    Utility-scale projects are increasingly paired with 2–4+ hour storage to firm output and capture higher-value evening/peak pricing, with continued growth in grid-scale storage buildouts.
#
# 2. **Grid connection, transmission, and “flexibility” as the binding constraint**
#    The main limiter in many markets is no longer generation cost—it’s interconnection queues, transmission buildout, and system flexibility (storage, demand response, fast-ramping assets).
#
# 3. **Solar keeps leading globally, but growth shifts by region and policy design**
#    Solar remains the largest driver of new renewable additions; however, market growth is uneven (high concentration in China), and policy/market-design changes can create short-term volatility (including a likely global growth dip around 2026 per SolarPower Europe).
#
# 4. **Offshore wind: reset + selective acceleration (especially where auctions/PPAs are bankable)**
#    Offshore wind is still a major growth pillar, but 2026 continues the “repricing/reset” era (inflation, supply chain, financing) with a shift toward better risk allocation, more corporate offtake, and staged project structures.
#
# 5. **Supply-chain localization and industrial policy intensify**
#    Countries are pushing domestic manufacturing and local content for solar, wind, and batteries; at the same time, turbine supply is increasingly China-led by shipment share.
#
# ---
#
# ## Who’s leading globally in **solar** and **wind** adoption (project developers/operators)
#
# ### Solar (major global developers/operators)
# These companies consistently show up as top large-scale solar developers/operators internationally (utility-scale portfolios, multi-country pipelines):
# - **Enel Green Power (Enel)**
# - **TotalEnergies**
# - **Lightsource bp**
# - **Adani Green Energy**
# - **EDF Renewables**
#
# *(Note: China’s state-backed power groups are also enormous solar builders, but global “leader” lists vary depending on whether you measure domestic installs, overseas portfolios, or developer vs. EPC roles.)*
#
# ### Wind (major global developers/operators)
# - **Ørsted** (clear leader in offshore wind; >18 GW total renewables installed, and ~10 GW installed offshore)
# - **Iberdrola**
# - **NextEra Energy**
# - **RWE**
# - **Vattenfall / SSE Renewables / EDF Renewables** (often cited among top owners/builders in major markets)
#
# ---
#
# ## Quick clarification (so “leaders” matches what you mean)
# When you say “leading in adoption,” do you mean **(a)** biggest *owners/operators by installed GW*, **(b)** biggest *developers by pipeline/annual additions*, or **(c)** biggest *equipment makers* (e.g., Vestas/Goldwind/Siemens Gamesa)? If you tell me which, I’ll rank the top 10 with a tighter definition.[US federal court grants preliminary injunction allowing Revolution Wind ...](https://orsted.com/en/media/news/2026/01/us-federal-court-grants-preliminary-injunction-all-1474935811)[Top 7 Largest Wind Farm Projects by Ørsted 2025](https://www.blackridgeresearch.com/blog/latest-list-upcoming-largest-wind-farm-project-orsted)[Offshore Wind Capacity Expands in Germany with Ørsted’s Largest Project ...](https://news.europawire.eu/offshore-wind-capacity-expands-in-germany-with-orsteds-largest-project-now-feeding-into-the-grid/eu-press-release/2025/12/04/11/56/41/166337/)
#
# ================================================================================
# Citations:
# ================================================================================
#
# [1] [US federal court grants preliminary injunction allowing Revolution Wind ...](https://orsted.com/en/media/news/2026/01/us-federal-court-grants-preliminary-injunction-all-1474935811)
#     URL: https://orsted.com/en/media/news/2026/01/us-federal-court-grants-preliminary-injunction-all-1474935811
#     Title: US federal court grants preliminary injunction allowing Revolution Wind ...
#
# [2] [Top 7 Largest Wind Farm Projects by Ørsted 2025](https://www.blackridgeresearch.com/blog/latest-list-upcoming-largest-wind-farm-project-orsted)
#     URL: https://www.blackridgeresearch.com/blog/latest-list-upcoming-largest-wind-farm-project-orsted
#     Title: Top 7 Largest Wind Farm Projects by Ørsted 2025
#
# [3] [Offshore Wind Capacity Expands in Germany with Ørsted’s Largest Project ...](https://news.europawire.eu/offshore-wind-capacity-expands-in-germany-with-orsteds-largest-project-now-feeding-into-the-grid/eu-press-release/2025/12/04/11/56/41/166337/)
#     URL: https://news.europawire.eu/offshore-wind-capacity-expands-in-germany-with-orsteds-largest-project-now-feeding-into-the-grid/eu-press-release/2025/12/04/11/56/41/166337/
#     Title: Offshore Wind Capacity Expands in Germany with Ørsted’s Largest Project ...
# ================================================================================
#
# ================================================================================
# Tool calls:
# ================================================================================
#
# Call 1:
# {
#   "id": "ws_035094baeb3c3d0c0069686c513c248190b9a877520128d884",
#   "action": {
#     "query": "2026 renewable energy trends solar wind grid batteries hydrogen",
#     "type": "search",
#     "sources": null
#   },
#   "status": "completed",
#   "type": "web_search_call"
# }
#
# Call 2:
# {
#   "id": "ws_035094baeb3c3d0c0069686c58cee48190bcaeecde1c84d29f",
#   "action": {
#     "type": "open_page",
#     "url": null
#   },
#   "status": "completed",
#   "type": "web_search_call"
# }
#
# Call 3:
# {
#   "id": "ws_035094baeb3c3d0c0069686c5c1e1481909e3654c3e50faa45",
#   "action": {
#     "query": "IEA Renewables 2025 key findings grid integration financing manufacturing trends",
#     "type": "search",
#     "sources": null
#   },
#   "status": "completed",
#   "type": "web_search_call"
# }
#
# Call 4:
# {
#   "id": "ws_035094baeb3c3d0c0069686c61780481908ad5e1d7190d59eb",
#   "action": {
#     "query": "largest solar power producers developers global portfolio Enel Green Power Iberdrola NextEra EDF Renewables Acciona solar",
#     "type": "search",
#     "sources": null
#   },
#   "status": "completed",
#   "type": "web_search_call"
# }
# ================================================================================
# Response(id='resp_035094baeb3c3d0c0069686c508554819094b9c845b1df9861', created_at=1768451152.0, error=None, incomplete_details=None, instructions=None, metadata={}, model='gpt-5.2', object='response', output=[ResponseFunctionWebSearch(id='ws_035094baeb3c3d0c0069686c513c248190b9a877520128d884', action=ActionSearch(query='2026 renewable energy trends solar wind grid batteries hydrogen', type='search', sources=None), status='completed', type='web_search_call'), ResponseFunctionWebSearch(id='ws_035094baeb3c3d0c0069686c58cee48190bcaeecde1c84d29f', action=ActionOpenPage(type='open_page', url=None), status='completed', type='web_search_call'), ResponseFunctionWebSearch(id='ws_035094baeb3c3d0c0069686c5c1e1481909e3654c3e50faa45', action=ActionSearch(query='IEA Renewables 2025 key findings grid integration financing manufacturing trends', type='search', sources=None), status='completed', type='web_search_call'), ResponseFunctionWebSearch(id='ws_035094baeb3c3d0c0069686c61780481908ad5e1d7190d59eb', action=ActionSearch(query='largest solar power producers developers global portfolio Enel Green Power Iberdrola NextEra EDF Renewables Acciona solar', type='search', sources=None), status='completed', type='web_search_call'), ResponseOutputMessage(id='msg_035094baeb3c3d0c0069686c69953c819091996e74587a3720', content=[ResponseOutputText(annotations=[AnnotationURLCitation(end_index=3043, start_index=2862, title='US federal court grants preliminary injunction allowing Revolution Wind ...', type='url_citation', url='https://orsted.com/en/media/news/2026/01/us-federal-court-grants-preliminary-injunction-all-1474935811'), AnnotationURLCitation(end_index=3187, start_index=3043, title='Top 7 Largest Wind Farm Projects by Ørsted 2025', type='url_citation', url='https://www.blackridgeresearch.com/blog/latest-list-upcoming-largest-wind-farm-project-orsted'), AnnotationURLCitation(end_index=3434, start_index=3187, title='Offshore Wind Capacity Expands in Germany with Ørsted’s Largest Project ...', type='url_citation', url='https://news.europawire.eu/offshore-wind-capacity-expands-in-germany-with-orsteds-largest-project-now-feeding-into-the-grid/eu-press-release/2025/12/04/11/56/41/166337/')], text='## Top 5 renewable energy trends shaping **2026**\n1. **Hybrid renewables (solar/wind + batteries) becoming the default**  \n   Utility-scale projects are increasingly paired with 2–4+ hour storage to firm output and capture higher-value evening/peak pricing, with continued growth in grid-scale storage buildouts. \n\n2. **Grid connection, transmission, and “flexibility” as the binding constraint**  \n   The main limiter in many markets is no longer generation cost—it’s interconnection queues, transmission buildout, and system flexibility (storage, demand response, fast-ramping assets). \n\n3. **Solar keeps leading globally, but growth shifts by region and policy design**  \n   Solar remains the largest driver of new renewable additions; however, market growth is uneven (high concentration in China), and policy/market-design changes can create short-term volatility (including a likely global growth dip around 2026 per SolarPower Europe). \n\n4. **Offshore wind: reset + selective acceleration (especially where auctions/PPAs are bankable)**  \n   Offshore wind is still a major growth pillar, but 2026 continues the “repricing/reset” era (inflation, supply chain, financing) with a shift toward better risk allocation, more corporate offtake, and staged project structures. \n\n5. **Supply-chain localization and industrial policy intensify**  \n   Countries are pushing domestic manufacturing and local content for solar, wind, and batteries; at the same time, turbine supply is increasingly China-led by shipment share. \n\n---\n\n## Who’s leading globally in **solar** and **wind** adoption (project developers/operators)\n\n### Solar (major global developers/operators)\nThese companies consistently show up as top large-scale solar developers/operators internationally (utili ...

# %% [markdown]
# ### Location-aware lookup
# Optionally bias results by providing an approximate country code.

# %%
location_tools = [
    {
        "type": "web_search_preview",
        "user_location": {"type": "approximate", "country": country or "US"},
    }
]

run_search(
    "Share a positive news story from the web today.",
    tools=location_tools,
)
# Out:
# Here is a positive news story from today:
#
# An inspiring story from the Good News Network highlights how an 11-year-old's White House dream came true, and 30 years later, he paid it forward in a heartwarming full-circle moment. This charming story celebrates the power of dreams and giving back to the community. You can read more about uplifting stories like this at Good News Network [source](https://www.goodnewsnetwork.org/).
#
# If you want another type of good news or stories from a specific area or topic, just let me know!
#
# ================================================================================
# Citations:
# ================================================================================
#
# [1] [source](https://www.goodnewsnetwork.org/)
#     URL: https://www.goodnewsnetwork.org/
#     Title: Good News, Inspiring, Positive Stories - Good News Network
# ================================================================================
#
# ================================================================================
# Tool calls:
# ================================================================================
#
# Call 1:
# {
#   "id": "ws_0dcaba71910d977a006966c38755248190a26d0ab18c20fd87",
#   "action": {
#     "query": "positive news today",
#     "type": "search",
#     "sources": null
#   },
#   "status": "searching",
#   "type": "web_search_call"
# }
# ================================================================================
# Response(id='resp_0dcaba71910d977a006966c386f2488190b4027e8e8cabc610', created_at=1768342406.0, error=None, incomplete_details=None, instructions=None, metadata={}, model='gpt-4.1-mini', object='response', output=[ResponseFunctionWebSearch(id='ws_0dcaba71910d977a006966c38755248190a26d0ab18c20fd87', action=ActionSearch(query='positive news today', type='search', sources=None), status='searching', type='web_search_call'), ResponseOutputMessage(id='msg_0dcaba71910d977a006966c38823d88190b5aabcc77fbde4e6', content=[ResponseOutputText(annotations=[AnnotationURLCitation(end_index=427, start_index=385, title='Good News, Inspiring, Positive Stories - Good News Network', type='url_citation', url='https://www.goodnewsnetwork.org/')], text="Here is a positive news story from today:\n\nAn inspiring story from the Good News Network highlights how an 11-year-old's White House dream came true, and 30 years later, he paid it forward in a heartwarming full-circle moment. This charming story celebrates the power of dreams and giving back to the community. You can read more about uplifting stories like this at Good News Network [source](https://www.goodnewsnetwork.org/).\n\nIf you want another type of good news or stories from a specific area or topic, just let me know!", type='output_text', logprobs=[])], role='assistant', status='completed', type='message')], parallel_tool_calls=True, temperature=1.0, tool_choice='auto', tools=[WebSearchPreviewTool(type='web_search_preview', search_context_size='medium', user_location=UserLocation(type='approximate', city=None, country='US', region=None, timezone=None))], top_p=1.0, background=False, conversation=None, max_output_tokens=None, max_tool_calls=None, previous_response_id=None, prompt=None, prompt_cache_key=None, reasoning=Reasoning(effort=None, generate_summary=None, summary=None), safety_identifier=None, service_tier='default', status='completed', text=ResponseTextConfig(format=ResponseFormatText(type='text'), verbosity='medium'), top_logprobs=0, truncation='disabled', usage=ResponseUsage(input_tokens=7171, input_tokens_details=InputTokensDetails(cached_tokens=0), output_tokens=127, output_tokens_details=OutputTokensDetails(reasoning_tokens=0), total_tokens=7298), user=None, content_filters=[{'blocked': False, 'source_type': 'prompt', 'content_filter_raw': None, 'content_filter_results': {'violence': {'filtered': False, 'severity': 'safe'}, 'jailbreak': {'filtered': False, 'detected': False}, 'hate': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}}, 'content_filter_offsets': {'start_offset': 30, 'end_offset': 77, 'check_offset': 0}}, {'blocked': False, 'source_type': 'completion', 'content_filter_raw': None, 'content_filter_results': {'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'hate': {'filtered': False, 'severity': 'low'}, 'violence': {'filtered': False, 'severity': 'low'}, 'protected_material_text': {'filtered': False, 'detected': False}, 'protected_material_code': {'filtered': False, 'detected': False}}, 'content_filter_offsets': {'start_offset': 0, 'end_offset': 30658, 'check_offset': 0}}], prompt_cache_retention=None, store=True)

# %% [markdown]
# ### Deep research (multi-step)
# Includes the `code_interpreter` tool to let the model perform extended reasoning. Requires a deployment that supports `o3-deep-research`.

# %%
print(deep_model)

if deep_model:
    run_search(
        "Research What are the top 5 renewable energy trends in 2026, and which companies are leading in solar and wind adoption globally?",
        tools=[
            {"type": "web_search_preview"},
            #{"type": "code_interpreter", "container": {"type": "auto"}},
        ],
        model_override=deep_model,
    )
else:
    print("Skip deep research demo; set AZURE_OPENAI_DEEP_MODEL to enable.")
# Out:
# o3-pro
# Top 5 renewable-energy trends to watch in 2026
#
# 1. Long-duration energy storage goes mainstream
#    • Prices for next-generation lithium-silicon, sodium-ion and flow batteries continue to fall, and more than 30 GW of stand-alone or co-located storage is expected to be commissioned worldwide in 2026. Utilities and developers are pairing solar and wind with four-hour-plus batteries to supply “clean-firm” power and to qualify for capacity and grid-services revenues.
#
# 2. Green hydrogen moves from pilots to first-wave commercial hubs
#    • Policy clarity in the EU’s Delegated Acts and multigigawatt auctions in India and the Middle East are triggering final-investment decisions for 100 MW-scale electrolyser projects. Electrolyser costs have dropped below US $500 per kW, opening a viable pathway to decarbonise steel, fertiliser and heavy transport.
#
# 3. Offshore—and now floating—wind scales rapidly
#    • Fixed-bottom additions in China, the North Sea and the U.S. Atlantic will lift global offshore wind capacity past 100 GW in 2026, while the first 200-MW-class floating arrays off Portugal and South Korea prove commercial bankability. Hybrid “wind-plus-hydrogen” platforms are entering early construction.
#
# 4. High-efficiency solar: perovskites, tandems and BIPV
#    • Commercial perovskite-silicon tandem modules exceeding 28 % efficiency start shipping from lines in China and Europe; building-integrated PV (BIPV) and floating-solar demand soars in land-constrained markets, pushing global PV installations toward 400 GW in 2026.
#
# 5. AI-driven smart grids and virtual power plants (VPPs)
#    • Surging data-centre electricity demand is straining grids; operators are responding with AI-optimised demand response, distributed batteries and aggregated DER/VPP platforms that can provide ancillary services in minutes. 24 / 7 carbon-free-energy procurement models pioneered by big tech accelerate this digitalisation push.
#
# ————————————————————————
# 2026 leaders in solar and wind adoption (utility-scale ownership or corporate offtake)
#
# A. Solar power (utility-scale PV ownership, end-2025 capacities)
# 1. State Power Investment Corporation (SPIC, China) – ≈ 16.4 GWac of utility-scale PV, the world’s largest owner.
# 2. NextEra Energy Resources (USA) – ≈ 12.4 GWac; continues to dominate North American solar growth.
# 3. Enel Green Power (Italy/global) – ≈ 11.7 GWac across five continents.
# 4. ENGIE (France/global) – ≈ 11.1 GWac of PV in operation after a record 2024 build-out.
# 5. Adani Green Energy (India) – ≈ 7 GWac, the fastest-growing solar owner in Asia.
#
# B. Wind power (leading developers/operators)
# 1. Ørsted (Denmark) – ~18 GW total wind capacity, including 10.2 GW of operating offshore wind—the largest global offshore portfolio.
# 2. NextEra Energy Resources (USA) – operates 126 wind projects, making it the world’s largest wind-and-solar operator by project count and total output.
# 3. RWE (Germany/global) – > 19 GW of wind (≈ 3.3 GW offshore, 15 + GW onshore) after rapid 2024-25 expansion.
# 4. Iberdrola/Avangrid (Spain/USA) – ≈ 2.4 GW offshore and a double-digit-GW onshore fleet, cementing its place among the top five global wind owners.
# 5. China Three Gorges Corporation (CTG, China) – major on- and offshore wind investor; in the global top-10 offshore developers with multi-GW pipeline and operating fleet.
#
# Corporate renewable buyers
# • Amazon remains the largest corporate purchaser of solar and wind for the fifth straight year, with >600 projects totaling over 100 GW of contracted clean energy—enough to power ~8 million U.S. homes.
#
# These companies and technology trends define the front line of renewable-energy deployment as 2026 begins, setting the pace for the sector’s growth through the rest of the decade.
#
# ================================================================================
# Citations:
# ================================================================================
#
# [1] a) – major on- and offshore wind investor; in the global top-10 offshore developers with multi-GW pipeline and operating fleet.
#
# Corporate renewable buyers
# • Amazon remains the largest corporate purchaser of solar and wind for the fifth straight yea
#     URL: https://www.rwe.com/-/media/RWE/documents/05-investor-relations/finanzkalendar-und-veroeffentlichungen/2025-Q3/25-10-23-rwe-q1-q3-2025-pre-release-capacity-and-power-generation-data.pdf
#     Title: Q1-Q3 2025 installed capacity and power generation data - rwe.com
#
# [2]
#     URL: https://wwindea.org/ss-uploads/media/2025/11/1762774319-1833f696-4ee8-43ce-95c2-9c8c48f43790.pdf
#     Title: WWEA Half-year Report 2025 - wwindea.org
#
# [3]
#     URL: https://windinsider.com/2025/08/16/rwe-posts-e2-1-billion-adjusted-ebitda-in-first-half-of-2025-on-track-to-meet-full-year-targets/
#     Title: RWE Posts €2.1 Billion Adjusted EBITDA in First Half of 2025, On Track ...
# ================================================================================
#
# ================================================================================
# Tool calls:
# ================================================================================
#
# Call 1:
# {
#   "id": "ws_0ef2f6232832356b0069686ed858b881958bb228d5bc1ca864",
#   "action": {
#     "query": "2026 renewable energy trends top 5 2026 green hydrogen energy storage virtual power plants corporate PPA",
#     "type": "search",
#     "sources": null
#   },
#   "status": "completed",
#   "type": "web_search_call"
# }
#
# Call 2:
# {
#   "id": "ws_0ef2f6232832356b0069686ed8726c8195b6e4bf4911a0567a",
#   "action": {
#     "query": "largest solar power plant operators 2025 worldwide installed capacity",
#     "type": "search",
#     "sources": null
#   },
#   "status": "completed",
#   "type": "web_search_call"
# }
#
# Call 3:
# {
#   "id": "ws_0ef2f6232832356b0069686ed886bc8195ac94edaf8781b608",
#   "action": {
#     "query": "top renewable energy trends 2026 green hydrogen, energy storage 2026",
#     "type": "search",
#     "sources": null
#   },
#   "status": "completed",
#   "type": "web_search_call"
# }
#
# Call 4:
# {
#   "id": "ws_0ef2f6232832356b0069686ed89a2481959f19a03e02c60173",
#   "action": {
#     "query": "largest corporate renewable energy purchasers 2025 amazon google",
#     "type": "search",
#     "sources": null
#   },
#   "status": "completed",
#   "type": "web_search_call"
# }
#
# Call 5:
# {
#   "id": "ws_0ef2f6232832356b0069686ed8a8748195b874bfa0d243c6bb",
#   "action": {
#     "query": "2025 top corporate renewable energy buyers 2025 report CEBA",
#     "type": "search",
#     "sources": null
#   },
#   "status": "completed",
#   "type": "web_search_call"
# }
#
# Call 6:
# {
#   "id": "ws_0ef2f6232832356b0069686ed8b0a48195a08412dacb25dd04",
#   "action": {
#     "query": "largest wind power operators 2025 company installed capacity ranking",
#     "type": "search",
#     "sources": null
#   },
#   "status": "completed",
#   "type": "web_search_call"
# }
#
# Call 7:
# {
#   "id": "ws_0ef2f6232832356b0069686ed8b8488195b7725f3f9522628f",
#   "action": {
#     "query": "largest wind power asset owners 2025 global",
#     "type": "search",
#     "sources": null
#   },
#   "status": "completed",
#   "type": "web_search_call"
# }
#
# Call 8:
# {
#   "id": "ws_0ef2f6232832356b0069686ed8c7d881959fa54731f50b56a3",
#   "action": {
#     "query": "top wind power asset owners 2025 next era energy orsted state power investment",
#     "type": "search",
#     "sources": null
#   },
#   "status": "completed",
#   "type": "web_search_call"
# }
#
# Call 9:
# {
#   "id": "ws_0ef2f6232832356b0069686ed8d5888195b244625586d5b26f",
#   "action": {
#     "query": "top wind asset owners 2025 ranking",
#     "type": "search",
#     "sources": null
#   },
#   "status": "completed",
#   "type": "web_search_call"
# }
#
# Call 10:
# {
#   "id": "ws_0ef2f6232832356b0069686ed8e25481959f995b7b79e5467a",
#   "action": {
#     "query": "largest wind power company by installed capacity 2025",
#     "type": "search",
#     "sources": null
#   },
#   "status": "completed",
#   "type": "web_search_call"
# }
#
# Call 11:
# {
#   "id": "ws_0ef2f6232832356b0069686ed8ed748195b55d944e94c13996",
#   "action": {
#     "query": "NextEra Energy total wind capacity 2025",
#     "type": "search",
#     "sources": null
#   },
#   "status": "completed",
#   "type": "web_search_call"
# }
#
# Call 12:
# {
#   "id": "ws_0ef2f6232832356b0069686ed903f4819595b71f89436b3fa3",
#   "action": {
#     "query": "NextEra Energy wind capacity 22 GW 2025",
#     "type": "search",
#     "sources": null
#   },
#   "status": "completed",
#   "type": "web_search_call"
# }
#
# Call 13:
# {
#   "id": "ws_0ef2f6232832356b0069686ed9187c81959f89e1fba6669f80",
#   "action": {
#     "query": "RWE total wind capacity 2025",
#     "type": "search",
#     "sources": null
#   },
#   "status": "completed",
#   "type": "web_search_call"
# }
# ================================================================================

# %%
run_search(
    "Client:A1292382 " \
    " SSN: 123482102" \
    " holdings: 100 AAPL, 200 NVDA.  Search latest news on my holdings and help me analyze my portfolio risks and suggest diversification strategies.",
    tools=[{"type": "web_search_preview"}]

)
# Out:
# Here is the latest news summary and analysis for your holdings:
#
# **Apple Inc. (AAPL)**
# - Apple recently announced a multi-year partnership with Google to enhance its AI capabilities, specifically improving Siri by integrating Google's Gemini AI models. This collaboration is expected to accelerate Apple's time-to-market for AI features across devices while managing costs efficiently.
# - Strong iPhone sales are anticipated for the upcoming fiscal quarter, potentially boosting Apple's revenue and investor confidence.
# - Analysts are generally bullish on Apple, reaffirming buy ratings with optimistic price targets ahead of the upcoming earnings report on January 29, 2026.
# - Risks include regulatory scrutiny, especially around AI implementations in various regions and ongoing tensions related to tech sector regulations.
# - Overall, Apple maintains a strong market position with a mix of innovation in AI and solid hardware sales.
#
# **NVIDIA Corporation (NVDA)**
# - NVIDIA showcased key product announcements at the CES 2026 event, including new AI-powered technologies and hardware enhancements to drive enterprise adoption and higher-margin revenue streams.
# - The company is poised for significant growth driven by strong demand for AI chips, particularly in data centers, and strategic partnerships such as the $1 billion AI co-innovation lab with Eli Lilly.
# - There is optimism from analysts with multiple buy/ outperform ratings and raised price targets; however, short-term volatility exists due to regulatory uncertainties, particularly around China shipments and trade issues.
# - Long-term demand drivers include AI infrastructure, autonomous driving, and expanding applications in physical AI and robotics.
#
# ---
#
# ### Portfolio Risk Analysis:
# - **Concentration risk**: Your holdings are concentrated in two major tech companies, both with high market capitalizations but sensitive to tech-sector cycles and regulatory environments.
# - **Sector risk**: Heavy exposure to technology, especially AI and semiconductors, subjects your portfolio to specific sector risks like supply chain issues, regulatory changes, and rapid technological disruption.
# - **Geopolitical and regulatory risks**: Both companies face risks related to cross-border trade tensions (e.g., China) and increasing regulatory scrutiny on AI technologies and data privacy.
#
# ---
#
# ### Diversification Strategies:
# - **Sector diversification**: Consider diversifying into other sectors such as healthcare, consumer staples, financials, or utilities to buffer against tech sector volatility.
# - **Geographic diversification**: Investing in international markets outside of the U.S., including emerging markets or Europe, may reduce geopolitical and regulatory exposure.
# - **Asset class diversification**: Include bonds, real estate investment trusts (REITs), or commodities to balance growth-oriented tech exposure with more stable or inflation-hedging assets.
# - **Thematic diversification within tech**: If maintaining tech exposure, diversify across sub-sectors (e.g., software, cloud, cybersecurity, fintech) and across company sizes (large cap vs. mid/small cap) to avoid company-specific risks.
#
# Would you like me to provide specific stock or fund recommendations to diversify your portfolio?
#
# ================================================================================
# Tool calls:
# ================================================================================
#
# Call 1:
# {
#   "id": "ws_0894f5757f27638a006966c48d6a44819098cea8871f58df61",
#   "action": {
#     "query": "latest news AAPL",
#     "type": "search",
#     "sources": null
#   },
#   "status": "searching",
#   "type": "web_search_call"
# }
#
# Call 2:
# {
#   "id": "ws_0894f5757f27638a006966c48e5ea081908c520232a3f1281f",
#   "action": {
#     "query": "latest news NVDA",
#     "type": "search",
#     "sources": null
#   },
#   "status": "searching",
#   "type": "web_search_call"
# }
# ================================================================================
# Response(id='resp_0894f5757f27638a006966c48d03008190b4d99921b1f53c5c', created_at=1768342669.0, error=None, incomplete_details=None, instructions=None, metadata={}, model='gpt-4.1-mini', object='response', output=[ResponseFunctionWebSearch(id='ws_0894f5757f27638a006966c48d6a44819098cea8871f58df61', action=ActionSearch(query='latest news AAPL', type='search', sources=None), status='searching', type='web_search_call'), ResponseFunctionWebSearch(id='ws_0894f5757f27638a006966c48e5ea081908c520232a3f1281f', action=ActionSearch(query='latest news NVDA', type='search', sources=None), status='searching', type='web_search_call'), ResponseOutputMessage(id='msg_0894f5757f27638a006966c48f541c8190baa73dcfa2ab6b59', content=[ResponseOutputText(annotations=[], text="Here is the latest news summary and analysis for your holdings:\n\n**Apple Inc. (AAPL)**  \n- Apple recently announced a multi-year partnership with Google to enhance its AI capabilities, specifically improving Siri by integrating Google's Gemini AI models. This collaboration is expected to accelerate Apple's time-to-market for AI features across devices while managing costs efficiently.  \n- Strong iPhone sales are anticipated for the upcoming fiscal quarter, potentially boosting Apple's revenue and investor confidence.  \n- Analysts are generally bullish on Apple, reaffirming buy ratings with optimistic price targets ahead of the upcoming earnings report on January 29, 2026.  \n- Risks include regulatory scrutiny, especially around AI implementations in various regions and ongoing tensions related to tech sector regulations.  \n- Overall, Apple maintains a strong market position with a mix of innovation in AI and solid hardware sales.  \n\n**NVIDIA Corporation (NVDA)**  \n- NVIDIA showcased key product announcements at the CES 2026 event, including new AI-powered technologies and hardware enhancements to drive enterprise adoption and higher-margin revenue streams.  \n- The company is poised for significant growth driven by strong demand for AI chips, particularly in data centers, and strategic partnerships such as the $1 billion AI co-innovation lab with Eli Lilly.  \n- There is optimism from analysts with multiple buy/ outperform ratings and raised price targets; however, short-term volatility exists due to regulatory uncertainties, particularly around China shipments and trade issues.  \n- Long-term demand drivers include AI infrastructure, autonomous driving, and expanding applications in physical AI and robotics.  \n\n---\n\n### Portfolio Risk Analysis:\n- **Concentration risk**: Your holdings are concentrated in two major tech companies, both with high market capitalizations but sensitive to tech-sector cycles and regulatory environments.  \n- **Sector risk**: Heavy exposure to technology, especially AI and semiconductors, subjects your portfolio to specific sector risks like supply chain issues, regulatory changes, and rapid technological disruption.  \n- **Geopolitical and regulatory risks**: Both companies face risks related to cross-border trade tensions (e.g., China) and increasing regulatory scrutiny on AI technologies and data privacy.  \n\n---\n\n### Diversification Strategies:\n- **Sector diversification**: Consider diversifying into other sectors such as healthcare, consumer staples, financials, or utilities to buffer against tech sector volatility.  \n- **Geographic diversification**: Investing in international markets outside of the U.S., including emerging markets or Europe, may reduce geopolitical and regulatory exposure.  \n- **Asset class diversification**: Include bonds, real estate investment trusts (REITs), or commodities to balance growth-oriented tech exposure with more stable or inflation-hedging assets.  \n- **Thematic diversification within tech**: If maintaining tech exposure, diversify across sub-sectors (e.g., software, cloud, cybersecurity, fintech) and across company sizes (large cap vs. mid/small cap) to avoid company-specific risks.  \n\nWould ...

# %% [markdown]
# ### Domain filtering
# Limit web search results to specific domains using the `filters` parameter with an allow-list of up to 100 URLs. When formatting URLs, omit the HTTP/HTTPS prefix (use `openai.com` instead of `https://openai.com/`). This includes subdomains in the search.
#
# The `sources` field returns the complete list of URLs consulted, which is often greater than inline citations. Real-time feeds are labeled as `oai-sports`, `oai-weather`, or `oai-finance`.

# %%
filtered_tools = [
    {
        "type": "web_search_preview",
        "filters": {
            "allowed_domains": [
                "pubmed.ncbi.nlm.nih.gov",
                "clinicaltrials.gov",
                "www.who.int",
                "www.cdc.gov",
                "www.fda.gov"
            ]
        }
    }
]

response = run_search(
    "Please perform a web search on how semaglutide is used in the treatment of diabetes.",
    tools=filtered_tools,
)

# Display sources if available
if hasattr(response, 'output') and response.output:
    sources = []
    for item in response.output:
        if hasattr(item, 'sources') and item.sources:
            sources.extend(item.sources)
    
    if sources:
        print("\n" + "=" * 80)
        print(f"Sources consulted ({len(sources)} total):")
        print("=" * 80)
        for i, source in enumerate(sources, 1):
            print(f"{i}. {source}")
        print("=" * 80)
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[12], line 16
#       1 filtered_tools = [
#       2     {
#       3         "type": "web_search_preview",
#    (...)
#      13     }
#      14 ]
# ---> 16 response = run_search(
#      17     "Please perform a web search on how semaglutide is used in the treatment of diabetes.",
#      18     tools=filtered_tools,
#      19 )
#      21 # Display sources if available
#      22 if hasattr(response, 'output') and response.output:
#
# Cell In[7], line 5, in run_search(prompt, tools, model_override)
#       4 def run_search(prompt: str, tools: List[dict], model_override: Optional[str] = None):
# ----> 5     response = client.responses.create(
#       6         model=model_override or model,
#       7         tools=tools,
#       8         input=prompt,
#       9     )
#      11     print(response.output_text)
#      13     # Display annotations (citations) if present
#
# File c:\Users\jacwang\AppData\Local\anaconda3\envs\oai\Lib\site-packages\openai\resources\responses\responses.py:828, in Responses.create(self, background, conversation, include, input, instructions, max_output_tokens, max_tool_calls, metadata, model, parallel_tool_calls, previous_response_id, prompt, prompt_cache_key, reasoning, safety_identifier, service_tier, store, stream, stream_options, temperature, text, tool_choice, tools, top_logprobs, top_p, truncation, user, extra_headers, extra_query, extra_body, timeout)
#     791 def create(
#     792     self,
#     793     *,
#    (...)
#     826     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     827 ) -> Response | Stream[ResponseStreamEvent]:
# --> 828     return self._post(
#     829         "/responses",
#     830         body=maybe_transform(
#     831             {
#     832                 "background": background,
#     833                 "conversation": conversation,
#     834                 "include": include,
#     835                 "input": input,
#     836                 "instructions": instructions,
#     837                 "max_output_tokens": max_output_tokens,
#     838                 "max_tool_calls": max_tool_calls,
#     839                 "metadata": metadata,
#     840                 "model": model,
#     841                 "parallel_tool_calls": parallel_tool_calls,
#     842                 "previous_response_id": previous_response_id,
#     843                 "prompt": prompt,
#     844                 "prompt_cache_key": prompt_cache_key,
#     845                 "reasoning": reasoning,
#     846                 "safety_identifier": safety_identifier,
#     847                 "service_tier": service_tier,
#     848                 "store": store,
#     849                 "stream": stream,
#     850                 "stream_options": stream_options,
#     851                 "temperature": temperature,
#     852                 "text": text,
#     853                 "tool_choice": tool_choice,
#     854                 "tools": tools,
#     855                 "top_logprobs": top_logprobs,
#     856                 "top_p": top_p,
#     857                 "truncation": truncation,
#     858                 "user": user,
#     859             },
#     860             response_create_params.ResponseCreateParamsStreaming
#     861             if stream
#     862             else response_create_params.ResponseCreateParamsNonStreaming,
#     863         ),
#     864         options=make_request_options(
#     865             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     866         ),
#     867         cast_to=Response,
#     868         stream=stream or False,
#     869         stream_cls=Stream[ResponseStreamEvent],
#     870     )
#
# File c:\Users\jacwang\AppData\Local\anaconda3\envs\oai\Lib\site-packages\openai\_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)
#    1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\jacwang\AppData\Local\anaconda3\envs\oai\Lib\site-packages\openai\_base_client.py:1047, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1044             err.response.read()
#    1046         log.debug("Re-raising status error")
# -> 1047         raise self._make_status_error_from_response(err.response) from None
#    1049     break
#    1051 assert response is not None, "could not resolve response (should never happen)"
#
# BadRequestError: Error code: 400 - {'error': {'message': "Unsupported parameter 'filters'", 'type': 'invalid_request_error', 'param': 'tools', 'code': None}}
