# %% [markdown]
# # Web Search quickstart
#
# Demonstrates Azure OpenAI Responses API with the `web_search` tool using environment variables loaded via `.env`.

# %% [markdown]
# ## Prerequisites
# - Install `openai` (>=1.56.0) and `python-dotenv`.
# - Populate `.env` with your Azure OpenAI settings. Supported keys (first match wins):
#   - Base URL: `AZURE_OPENAI_BASE_URL` | `AZURE_OPENAI_API_BASE` | `AZURE_EXISTING_AIPROJECT_ENDPOINT`
#   - Azure auth: `DefaultAzureCredential` + `get_bearer_token_provider` (run `az login` locally or use managed identity).
#   - Model deployment (optional): `AZURE_OPENAI_MODEL` | `AZURE_OPENAI_DEPLOYMENT` (default `gpt-4.1`)
#   - Country code (optional): `AZURE_OPENAI_COUNTRY` (for location-biased search)
#   - Deep research deployment (optional): `AZURE_OPENAI_DEEP_MODEL`
# - Using web search can incur costs and sends data to Bing for grounding.

# %%
# Optional setup: install dependencies if the kernel is missing them.
# If needed, install dependencies (uncomment to run)
# %pip install -U openai python-dotenv

# %%
# Load environment variables and normalize the Azure OpenAI base URL.
import os
from azure.identity import DefaultAzureCredential, get_bearer_token_provider
from dotenv import load_dotenv

load_dotenv(override=True)

base_url = (
    os.getenv("AZURE_OPENAI_BASE_URL")
    or os.getenv("AZURE_OPENAI_API_BASE")
    or os.getenv("AZURE_EXISTING_AIPROJECT_ENDPOINT")
)
token_provider = get_bearer_token_provider(
    DefaultAzureCredential(),
    "https://cognitiveservices.azure.com/.default",
)
model = os.getenv("AZURE_OPENAI_MODEL") or os.getenv("AZURE_OPENAI_DEPLOYMENT") or "gpt-5.2"
print(model)
country = os.getenv("AZURE_OPENAI_COUNTRY")
deep_model = os.getenv("AZURE_OPENAI_DEEP_MODEL")
# Optionally use a deep research model if configured in the environment.
print(deep_model)

if not base_url:
    raise ValueError("Set base URL in .env (see prerequisites).")

base_url = base_url.rstrip("/")
if not base_url.endswith("/openai/v1"):
    base_url = f"{base_url}/openai/v1"
# Out:
# gpt-5.2
# o3-pro

# %%
# Instantiate the OpenAI client for the Responses API.
from openai import OpenAI

client = OpenAI(api_key=token_provider, base_url=base_url)
print(f"Client ready against {base_url}")
# Out:
# Client ready against https://eu2-oai.openai.azure.com/openai/v1

# %%
# Helper utilities for invoking web search and printing structured output.
# This keeps the demo calls consistent and easy to compare.
import json
from typing import Optional, List

def run_search(prompt: str, tools: List[dict], model_override: Optional[str] = None):
    # Submit the prompt with the selected tools and capture the response.
    response = client.responses.create(
        model=model_override or model,
        tools=tools,
        input=prompt,
        tool_choice="required" #Optional if you want to enforce tool calling
    )

    # Print the main response text for quick inspection.
    print(response.output_text)

    # Display annotations (citations) if present
    messages = [item for item in response.output or [] if item.type == "message"]
    for message in messages:
        for content in message.content or []:
            if hasattr(content, 'annotations') and content.annotations:
                print("\n" + "=" * 80)
                print("Citations:")
                print("=" * 80)
                for i, annotation in enumerate(content.annotations, 1):
                    # Extract the cited text using start_index and end_index
                    if hasattr(annotation, 'start_index') and hasattr(annotation, 'end_index'):
                        cited_text = content.text[annotation.start_index:annotation.end_index]
                        print(f"\n[{i}] {cited_text}")
                    else:
                        print(f"\n[{i}] Citation {i}")
                    
                    # Display URL and title if available
                    if hasattr(annotation, 'url') and annotation.url:
                        print(f"    URL: {annotation.url}")
                    if hasattr(annotation, 'title') and annotation.title:
                        print(f"    Title: {annotation.title}")
                print("=" * 80)

    # Extract and display explicit tool calls for debugging.
    actions = [item for item in response.output or [] if item.type == "web_search_call"]
    if actions:
        print("\n" + "=" * 80)
        print("Tool calls:")
        print("=" * 80)
        for i, action in enumerate(actions, 1):
            try:
                print(f"\nCall {i}:")
                print(json.dumps(action.model_dump(), indent=2, ensure_ascii=False, sort_keys=False))
            except Exception:
                print(action)
        print("=" * 80)

    return response

# %% [markdown]
# ### Quick lookup (single search)
# Uses the fastest path: the model forwards the prompt directly to web search without multi-step planning.

# %%
# Quick lookup using the lightweight web search tool.
# Ask a multi-part question to exercise broader search coverage.
run_search(
    "What happened in the last NFL game?",
    tools=[{"type": "web_search"}],
)
# Out:
# As of **today (Monday, March 9, 2026)**, there **hasn’t been an NFL game recently**—the NFL is in the offseason and there are **no games scheduled this week**. ([onsportsnow.com](https://onsportsnow.com/nfl/schedule.php))
#
# The **most recent NFL game** was **Super Bowl LX on Sunday, February 8, 2026**: **Seattle Seahawks 29, New England Patriots 13**. ([espn.com](https://www.espn.com/nfl/schedule/_/season/1))
#
# If you tell me **which team** you mean, I can recap *their* most recent game.
#
# ================================================================================
# Citations:
# ================================================================================
#
# [1] ([onsportsnow.com](https://onsportsnow.com/nfl/schedule.php))
#     URL: https://onsportsnow.com/nfl/schedule.php
#     Title: NFL Schedule - March 9, 2026 to March 15, 2026 | OnSportsNow
#
# [2] ([espn.com](https://www.espn.com/nfl/schedule/_/season/1))
#     URL: https://www.espn.com/nfl/schedule/_/season/1
#     Title: NFL Schedule - 2026 Season - ESPN
# ================================================================================
#
# ================================================================================
# Tool calls:
# ================================================================================
#
# Call 1:
# {
#   "id": "ws_08e6ecef44dc40fb0069af4f41eea08195b5f0cf5e1a2858b1",
#   "action": {
#     "query": "sports: {\"tool\":\"sports\",\"fn\":\"schedule\",\"league\":\"nfl\",\"date_from\":\"2026-03-01\",\"date_to\":\"2026-03-09\",\"num_games\":20}",
#     "type": "search",
#     "sources": null,
#     "queries": [
#       "sports: {\"tool\":\"sports\",\"fn\":\"schedule\",\"league\":\"nfl\",\"date_from\":\"2026-03-01\",\"date_to\":\"2026-03-09\",\"num_games\":20}"
#     ]
#   },
#   "status": "completed",
#   "type": "web_search_call"
# }
# ================================================================================
# Response(id='resp_08e6ecef44dc40fb0069af4f40b8d48195bb67b55a6e026402', created_at=1773096768.0, error=None, incomplete_details=None, instructions=None, metadata={}, model='gpt-5.2', object='response', output=[ResponseFunctionWebSearch(id='ws_08e6ecef44dc40fb0069af4f41eea08195b5f0cf5e1a2858b1', action=ActionSearch(query='sports: {"tool":"sports","fn":"schedule","league":"nfl","date_from":"2026-03-01","date_to":"2026-03-09","num_games":20}', type='search', sources=None, queries=['sports: {"tool":"sports","fn":"schedule","league":"nfl","date_from":"2026-03-01","date_to":"2026-03-09","num_games":20}']), status='completed', type='web_search_call'), ResponseOutputMessage(id='msg_08e6ecef44dc40fb0069af4f461bfc8195943be650530f19bd', content=[ResponseOutputText(annotations=[AnnotationURLCitation(end_index=221, start_index=160, title='NFL Schedule - March 9, 2026 to March 15, 2026 | OnSportsNow', type='url_citation', url='https://onsportsnow.com/nfl/schedule.php'), AnnotationURLCitation(end_index=411, start_index=353, title='NFL Schedule - 2026 Season - ESPN', type='url_citation', url='https://www.espn.com/nfl/schedule/_/season/1')], text='As of **today (Monday, March 9, 2026)**, there **hasn’t been an NFL game recently**—the NFL is in the offseason and there are **no games scheduled this week**. ([onsportsnow.com](https://onsportsnow.com/nfl/schedule.php))\n\nThe **most recent NFL game** was **Super Bowl LX on Sunday, February 8, 2026**: **Seattle Seahawks 29, New England Patriots 13**. ([espn.com](https://www.espn.com/nfl/schedule/_/season/1))\n\nIf you tell me **which team** you mean, I can recap *their* most recent game.', type='output_text', logprobs=[])], role='assistant', status='completed', type='message')], parallel_tool_calls=True, temperature=1.0, tool_choice='required', tools=[WebSearchTool(type='web_search', filters=None, search_context_size='medium', user_location=UserLocation(city=None, country='US', region=None, timezone=None, type='approximate'))], top_p=0.98, background=False, conversation=None, max_output_tokens=None, max_tool_calls=None, previous_response_id=None, prompt=None, prompt_cache_key=None, reasoning=Reasoning(effort='none', generate_summary=None, summary=None), safety_identifier=None, service_tier='default', status='completed', text=ResponseTextConfig(format=ResponseFormatText(type='text'), verbosity='medium'), top_logprobs=0, truncation='disabled', usage=ResponseUsage(input_tokens=8322, input_tokens_details=InputTokensDetails(cached_tokens=0), output_tokens=194, output_tokens_details=OutputTokensDetails(reasoning_tokens=57), total_tokens=8516), user=None, completed_at=1773096776, content_filters=[{'blocked': False, 'source_type': 'prompt', 'content_filter_raw': [], 'content_filter_results': {'indirect_attack': {'detected': False, 'filtered': False}, 'hate': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'jailbreak': {'detected': False, 'filtered': False}}, 'content_filter_offsets': {'start_offset': 0, 'end_offset': 20049, 'check_offset': 0}}, {'blocked': False, 'source_type': 'completion', 'content_filter_raw': [], 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'protected_material_text': {'detected': False, 'filtered': False}, 'protected_material_code': {'detected': False, 'filtered': False}}, 'content_filter_offsets': {'start_offset': 0, 'end_offset': 16599, 'check_offset': 0}}], frequency_penalty=0.0, presence_penalty=0.0, prompt_cache_retention=None, store=True)

# %%
# Repeat the quick lookup to compare response variability.
run_search(
    "What happened in the last NFL game?",
    tools=[{"type": "web_search"}]
    ,
)
# Out:
# As of **today (Monday, March 9, 2026)**, the NFL is **in the offseason**, so there hasn’t been an NFL game in the last few days. ([usatoday.com](https://www.usatoday.com/story/sports/nfl/2026/03/05/nfl-offseason-calendar-2026-free-agency-draft-schedule/88860310007/))
#
# The **most recent NFL game** was **Super Bowl LX on Sunday, February 8, 2026**: the **Seattle Seahawks beat the New England Patriots 29–13**. ([espn.com](https://www.espn.com/nfl/schedule/_/season/1))
#
# If you tell me **which team** you mean (or whether you mean **regular season / playoffs / Super Bowl**), I can summarize that specific “last game” in detail.
#
# ================================================================================
# Citations:
# ================================================================================
#
# [1] ([usatoday.com](https://www.usatoday.com/story/sports/nfl/2026/03/05/nfl-offseason-calendar-2026-free-agency-draft-schedule/88860310007/))
#     URL: https://www.usatoday.com/story/sports/nfl/2026/03/05/nfl-offseason-calendar-2026-free-agency-draft-schedule/88860310007/
#     Title: NFL offseason calendar 2026: Free agency, draft, season schedule
#
# [2] ([espn.com](https://www.espn.com/nfl/schedule/_/season/1))
#     URL: https://www.espn.com/nfl/schedule/_/season/1
#     Title: NFL Schedule - 2026 Season - ESPN
# ================================================================================
#
# ================================================================================
# Tool calls:
# ================================================================================
#
# Call 1:
# {
#   "id": "ws_0962485007dabecf0069af4f5244408196b40bc004544776ef",
#   "action": {
#     "query": "sports: {\"tool\":\"sports\",\"fn\":\"schedule\",\"league\":\"nfl\",\"date_from\":\"2026-03-01\",\"date_to\":\"2026-03-09\",\"num_games\":20}",
#     "type": "search",
#     "sources": null,
#     "queries": [
#       "sports: {\"tool\":\"sports\",\"fn\":\"schedule\",\"league\":\"nfl\",\"date_from\":\"2026-03-01\",\"date_to\":\"2026-03-09\",\"num_games\":20}"
#     ]
#   },
#   "status": "completed",
#   "type": "web_search_call"
# }
# ================================================================================
# Response(id='resp_0962485007dabecf0069af4f4ff3888196a57fb13bb96a1aee', created_at=1773096783.0, error=None, incomplete_details=None, instructions=None, metadata={}, model='gpt-5.2', object='response', output=[ResponseFunctionWebSearch(id='ws_0962485007dabecf0069af4f5244408196b40bc004544776ef', action=ActionSearch(query='sports: {"tool":"sports","fn":"schedule","league":"nfl","date_from":"2026-03-01","date_to":"2026-03-09","num_games":20}', type='search', sources=None, queries=['sports: {"tool":"sports","fn":"schedule","league":"nfl","date_from":"2026-03-01","date_to":"2026-03-09","num_games":20}']), status='completed', type='web_search_call'), ResponseOutputMessage(id='msg_0962485007dabecf0069af4f5645b48196a5720bb12425335d', content=[ResponseOutputText(annotations=[AnnotationURLCitation(end_index=267, start_index=129, title='NFL offseason calendar 2026: Free agency, draft, season schedule', type='url_citation', url='https://www.usatoday.com/story/sports/nfl/2026/03/05/nfl-offseason-calendar-2026-free-agency-draft-schedule/88860310007/'), AnnotationURLCitation(end_index=469, start_index=411, title='NFL Schedule - 2026 Season - ESPN', type='url_citation', url='https://www.espn.com/nfl/schedule/_/season/1')], text='As of **today (Monday, March 9, 2026)**, the NFL is **in the offseason**, so there hasn’t been an NFL game in the last few days. ([usatoday.com](https://www.usatoday.com/story/sports/nfl/2026/03/05/nfl-offseason-calendar-2026-free-agency-draft-schedule/88860310007/))\n\nThe **most recent NFL game** was **Super Bowl LX on Sunday, February 8, 2026**: the **Seattle Seahawks beat the New England Patriots 29–13**. ([espn.com](https://www.espn.com/nfl/schedule/_/season/1))\n\nIf you tell me **which team** you mean (or whether you mean **regular season / playoffs / Super Bowl**), I can summarize that specific “last game” in detail.', type='output_text', logprobs=[])], role='assistant', status='completed', type='message')], parallel_tool_calls=True, temperature=1.0, tool_choice='required', tools=[WebSearchTool(type='web_search', filters=None, search_context_size='medium', user_location=UserLocation(city=None, country='US', region=None, timezone=None, type='approximate'))], top_p=0.98, background=False, conversation=None, max_output_tokens=None, max_tool_calls=None, previous_response_id=None, prompt=None, prompt_cache_key=None, reasoning=Reasoning(effort='none', generate_summary=None, summary=None), safety_identifier=None, service_tier='default', status='completed', text=ResponseTextConfig(format=ResponseFormatText(type='text'), verbosity='medium'), top_logprobs=0, truncation='disabled', usage=ResponseUsage(input_tokens=8349, input_tokens_details=InputTokensDetails(cached_tokens=4224), output_tokens=212, output_tokens_details=OutputTokensDetails(reasoning_tokens=57), total_tokens=8561), user=None, completed_at=1773096794, content_filters=[{'blocked': False, 'source_type': 'prompt', 'content_filter_raw': [], 'content_filter_results': {'indirect_attack': {'detected': False, 'filtered': False}, 'jailbreak': {'detected': False, 'filtered': False}, 'hate': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}}, 'content_filter_offsets': {'start_offset': 0, 'end_offset': 68, 'check_offset': 0}}, {'blocked': False, 'source_type': 'completion', 'content_filter_raw': [], 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'protected_material_code': {'detected': False, 'filtered': False}, 'protected_material_text': {'detected': False, 'filtered': False}}, 'content_filter_offsets': {'start_offset': 0, 'end_offset': 17066, 'check_offset': 0}}], frequency_penalty=0.0, presence_penalty=0.0, prompt_cache_retention=None, st ...

# %%
# Ask a multi-part question to exercise broader search coverage.
run_search(
    "What are the top 5 renewable energy trends in 2026, and which companies are leading in solar and wind adoption globally?",
    tools=[{"type": "web_search"}],
)
# Out:
# The top 5 renewable energy trends for 2026 are:
#
# 1. **Energy Storage Breakthroughs**: Wide deployment of next-gen batteries like lithium-silicon and sodium-ion, expansion of grid-scale storage systems, and growth in long-duration energy storage to balance intermittent sources like solar and wind.
#
# 2. **Solar Power Advancements**: Commercialization of perovskite solar cells offering higher efficiency and lower cost, expansion of floating solar farms, and increased use of Building-Integrated Photovoltaics (BIPV), integrating solar more seamlessly into buildings and urban infrastructure.
#
# 3. **Green Hydrogen Expansion**: More countries adopting national hydrogen strategies, declining electrolyzer costs, and the growth of hydrogen hubs in Europe, Asia, and the Middle East to support decarbonization of industries like steel and aviation.
#
# 4. **Offshore Wind Growth**: Significant increase in floating offshore wind projects unlocking deep-water sites with stronger, more consistent winds, with major projects in the North Sea, U.S. East Coast, and Asia-Pacific regions.
#
# 5. **Smart Grids and AI Integration**: Adoption of smart grids powered by AI and IoT for real-time demand-response, decentralized energy markets leveraging blockchain, and predictive analytics for optimized grid management.
#
# Regarding leading companies in global solar and wind adoption:
#
# - **Solar**: Companies like First Solar, SunPower, and Canadian Solar are notable leaders, with extensive solar farm deployments and strong innovation in PV technologies including perovskite cells and hybrid solar-plus-storage systems.
#
# - **Wind**: Leading companies include Vestas, Siemens Gamesa, and GE Renewable Energy, which dominate offshore and onshore wind turbine installations and are pioneers in floating offshore wind technology.
#
# These trends and leaders reflect the rapid technological advancements and scaling efforts fueling the global energy transition in 2026.
#
# Sources:
# - [Renewable Energy Trends 2026 - Renewable Energy Conference Blog](https://www.renewableenergyconference.org/blog/trends-in-renewable-energy-2026.html)
# - [Top Renewable Energy Trends 2026 - StartUs Insights](https://www.startus-insights.com/innovators-guide/renewable-energy-trends/)
# - [RatedPower 2026 Global Renewable Energy Trends Report](https://www.renewableenergymagazine.com/panorama/ratedpower-publishes-2026-global-renewable-energy-trends-20260227)
# - [HotBot - Top Renewable & Alternative Energy Trends in 2026](https://www.hotbot.com/articles/top-renewable-alternative-energy-trends-in-2026-solar-wind-green-innovation/)
#
# ================================================================================
# Citations:
# ================================================================================
#
# [1] [Renewable Energy Trends 2026 - Renewable Energy Conference Blog](https://www.renewableenergyconference.org/blog/trends-in-renewable-energy-2026.html)
#     URL: https://www.renewableenergyconference.org/blog/trends-in-renewable-energy-2026.html
#     Title: What Are the Top Trends in Renewable Energy for 2026?
#
# [2] [Top Renewable Energy Trends 2026 - StartUs Insights](https://www.startus-insights.com/innovators-guide/renewable-energy-trends/)
#     URL: https://www.startus-insights.com/innovators-guide/renewable-energy-trends/
#     Title: Top 10 Renewable Energy Trends in 2026 | StartUs Insights
#
# [3] [RatedPower 2026 Global Renewable Energy Trends Report](https://www.renewableenergymagazine.com/panorama/ratedpower-publishes-2026-global-renewable-energy-trends-20260227)
#     URL: https://www.renewableenergymagazine.com/panorama/ratedpower-publishes-2026-global-renewable-energy-trends-20260227
#     Title: RatedPower publishes 2026 Global Renewable Energy Trends Report
#
# [4] [HotBot - Top Renewable & Alternative Energy Trends in 2026](https://www.hotbot.com/articles/top-renewable-alternative-energy-trends-in-2026-solar-wind-green-innovation/)
#     URL: https://www.hotbot.com/articles/top-renewable-alternative-energy-trends-in-2026-solar-wind-green-innovation/
#     Title: Top Renewable & Alternative Energy Trends in 2026: Solar, Wind & Green ...
# ================================================================================
#
# ================================================================================
# Tool calls:
# ================================================================================
#
# Call 1:
# {
#   "id": "ws_0d694964ca8a75ef0069ae4be047fc81968ee6f02e9e3b1c59",
#   "action": {
#     "query": "top renewable energy trends 2026",
#     "type": "search",
#     "sources": null,
#     "queries": [
#       "top renewable energy trends 2026"
#     ]
#   },
#   "status": "searching",
#   "type": "web_search_call"
# }
# ================================================================================
# Response(id='resp_0d694964ca8a75ef0069ae4bdffb048196af1d1c1b105682b4', created_at=1773030367.0, error=None, incomplete_details=None, instructions=None, metadata={}, model='gpt-4.1-mini', object='response', output=[ResponseFunctionWebSearch(id='ws_0d694964ca8a75ef0069ae4be047fc81968ee6f02e9e3b1c59', action=ActionSearch(query='top renewable energy trends 2026', type='search', sources=None, queries=['top renewable energy trends 2026']), status='searching', type='web_search_call'), ResponseOutputMessage(id='msg_0d694964ca8a75ef0069ae4be1473881969d40f76ac9a446fe', content=[ResponseOutputText(annotations=[AnnotationURLCitation(end_index=2109, start_index=1959, title='What Are the Top Trends in Renewable Energy for 2026?', type='url_citation', url='https://www.renewableenergyconference.org/blog/trends-in-renewable-energy-2026.html'), AnnotationURLCitation(end_index=2241, start_index=2112, title='Top 10 Renewable Energy Trends in 2026 | StartUs Insights', type='url_citation', url='https://www.startus-insights.com/innovators-guide/renewable-energy-trends/'), AnnotationURLCitation(end_index=2415, start_index=2244, title='RatedPower publishes 2026 Global Renewable Energy Trends Report', type='url_citation', url='https://www.renewableenergymagazine.com/panorama/ratedpower-publishes-2026-global-renewable-energy-trends-20260227'), AnnotationURLCitation(end_index=2588, start_index=2418, title='Top Renewable & Alternative Energy Trends in 2026: Solar, Wind & Green ...', type='url_citation', url='https://www.hotbot.com/articles/top-renewable-alternative-energy-trends-in-2026-solar-wind-green-innovation/')], text='The top 5 renewable energy trends for 2026 are:\n\n1. **Energy Storage Breakthroughs**: Wide deployment of next-gen batteries like lithium-silicon and sodium-ion, expansion of grid-scale storage systems, and growth in long-duration energy storage to balance intermittent sources like solar and wind.\n\n2. **Solar Power Advancements**: Commercialization of perovskite solar cells offering higher efficiency and lower cost, expansion of floating solar farms, and increased use of Building-Integrated Photovoltaics (BIPV), integrating solar more seamlessly into buildings and urban infrastructure.\n\n3. **Green Hydrogen Expansion**: More countries adopting national hydrogen strategies, declining electrolyzer costs, and the growth of hydrogen hubs in Europe, Asia, and the Middle East to support decarbonization of industries like steel and aviation.\n\n4. **Offshore Wind Growth**: Significant increase in floating offshore wind projects unlocking deep-water sites with stronger, more consistent winds, with major projects in the North Sea, U.S. East Coast, and Asia-Pacific regions.\n\n5. **Smart Grids and AI Integration**: Adoption of smart grids powered by AI and IoT for real-time demand-response, decentralized energy markets leveraging blockchain, and predictive analytics for optimized grid management.\n\nRegarding leading companies in global solar and wind adoption:\n\n- **Solar**: Companies like First Solar, SunPower, and Canadian Solar are notable leaders, with extensive solar farm deployments and strong innovation in PV technologies including perovskite cells and hybrid solar-plus-storage systems.\n\n- **Wind**: Leading companies include Vestas, Siemens Gamesa, and GE Renewable Energy, which dominate offshore and onshore wind turbine installations and are pioneers in floating offshore wind technology.\n\nThese trends and leaders reflect the rapid technological advancements and scaling efforts fueling the global energy transition in 2026. \n\nSources:\n- [Renewable Energy Trends 2026 - Renewable Energy Conference Blog](https://www.renewableenergyconference.org/blog/trends-in-renewable-energy-2026.html)\n- [Top Renewable Energy Trends 2026 - StartUs Insights](https://www.startus-insights.com/innovators-guide/renewable-energy-trends/)\n- [RatedPower 2026 Global Renewable Energy Trends Report](https://www.renewableenergymagazine.com/panorama/rate ...

# %%
# Repeat the multi-part prompt to compare consistency.
run_search(
    "What are the top 5 renewable energy trends in 2026, and which companies are leading in solar and wind adoption globally?",
    tools=[{"type": "web_search"}],
)
# Out:
# The top 5 renewable energy trends in 2026 are:
#
# 1. **Policy Shifts**: Changes in policy, such as tighter qualification windows for tax credits and new sourcing restrictions, are affecting project economics. Despite some setbacks, renewables still dominate capacity growth, and developers are focusing on near-term deployments and supply chain resilience.
#
# 2. **Energy Storage Integration**: Growth in battery energy storage, including grid-scale and long-duration energy storage (LDES), is critical to balance intermittent sources like solar and wind and support 24/7 clean energy availability.
#
# 3. **Solar Power Advancements**: Innovations like perovskite solar cells with higher efficiency and lower cost, floating solar farms, and building-integrated photovoltaics (BIPV) are making solar more prevalent and integrated into infrastructure.
#
# 4. **Offshore Wind Expansion**: Offshore wind, especially floating offshore wind, is growing rapidly, unlocking deeper water sites with stronger winds. Major projects are underway in areas like the North Sea, U.S. East Coast, and Asia-Pacific.
#
# 5. **Digital and AI Integration**: Smart grids using AI and IoT enable real-time demand response, predictive analytics for grid management, and decentralized energy markets, making energy systems more efficient and resilient.
#
# Additional trends include green hydrogen scaling, bioenergy innovations, and increased ESG investment and policy attention.
#
# Regarding companies leading in solar and wind adoption globally in 2026:
#
# - **Solar Leaders**: Companies like First Solar, JinkoSolar, Canadian Solar, and LONGi Solar lead in solar panel manufacturing and deployment globally.
# - **Wind Leaders**: Vestas, Siemens Gamesa, GE Renewable Energy, and Goldwind dominate the wind turbine manufacturing and wind farm development sectors worldwide.
#
# These companies have robust technological innovation, large operational scale, and strong market presence, enabling them to lead renewable energy adoption internationally.
#
# Sources:
# - Deloitte 2026 Renewable Energy Industry Outlook
# - StartUs Insights: Top 10 Renewable Energy Trends in 2026
# - RatedPower 2026 Global Renewable Energy Trends Report
# - RenewableEnergyConference.org: Top Trends for 2026
# - Bitget: Top Renewable Energy Companies to Watch in 2026
# - HotBot.com: Top Renewable & Alternative Energy Trends in 2026
#
# If you want, I can provide more detailed company info or trends.
#
# ================================================================================
# Tool calls:
# ================================================================================
#
# Call 1:
# {
#   "id": "ws_07f95eb1977c9d3a0069ae4be873cc8193b3822f0878a7708a",
#   "action": {
#     "query": "2026 renewable energy trends solar wind leading companies",
#     "type": "search",
#     "sources": null,
#     "queries": [
#       "2026 renewable energy trends solar wind leading companies"
#     ]
#   },
#   "status": "searching",
#   "type": "web_search_call"
# }
# ================================================================================
# Response(id='resp_07f95eb1977c9d3a0069ae4be7042081938ef3f8e743cdc308', created_at=1773030375.0, error=None, incomplete_details=None, instructions=None, metadata={}, model='gpt-4.1-mini', object='response', output=[ResponseFunctionWebSearch(id='ws_07f95eb1977c9d3a0069ae4be873cc8193b3822f0878a7708a', action=ActionSearch(query='2026 renewable energy trends solar wind leading companies', type='search', sources=None, queries=['2026 renewable energy trends solar wind leading companies']), status='searching', type='web_search_call'), ResponseOutputMessage(id='msg_07f95eb1977c9d3a0069ae4be9a2248193b6a16c166e47ccf8', content=[ResponseOutputText(annotations=[], text='The top 5 renewable energy trends in 2026 are:\n\n1. **Policy Shifts**: Changes in policy, such as tighter qualification windows for tax credits and new sourcing restrictions, are affecting project economics. Despite some setbacks, renewables still dominate capacity growth, and developers are focusing on near-term deployments and supply chain resilience.\n\n2. **Energy Storage Integration**: Growth in battery energy storage, including grid-scale and long-duration energy storage (LDES), is critical to balance intermittent sources like solar and wind and support 24/7 clean energy availability.\n\n3. **Solar Power Advancements**: Innovations like perovskite solar cells with higher efficiency and lower cost, floating solar farms, and building-integrated photovoltaics (BIPV) are making solar more prevalent and integrated into infrastructure.\n\n4. **Offshore Wind Expansion**: Offshore wind, especially floating offshore wind, is growing rapidly, unlocking deeper water sites with stronger winds. Major projects are underway in areas like the North Sea, U.S. East Coast, and Asia-Pacific.\n\n5. **Digital and AI Integration**: Smart grids using AI and IoT enable real-time demand response, predictive analytics for grid management, and decentralized energy markets, making energy systems more efficient and resilient.\n\nAdditional trends include green hydrogen scaling, bioenergy innovations, and increased ESG investment and policy attention.\n\nRegarding companies leading in solar and wind adoption globally in 2026:\n\n- **Solar Leaders**: Companies like First Solar, JinkoSolar, Canadian Solar, and LONGi Solar lead in solar panel manufacturing and deployment globally.\n- **Wind Leaders**: Vestas, Siemens Gamesa, GE Renewable Energy, and Goldwind dominate the wind turbine manufacturing and wind farm development sectors worldwide.\n\nThese companies have robust technological innovation, large operational scale, and strong market presence, enabling them to lead renewable energy adoption internationally.\n\nSources:\n- Deloitte 2026 Renewable Energy Industry Outlook\n- StartUs Insights: Top 10 Renewable Energy Trends in 2026\n- RatedPower 2026 Global Renewable Energy Trends Report\n- RenewableEnergyConference.org: Top Trends for 2026\n- Bitget: Top Renewable Energy Companies to Watch in 2026\n- HotBot.com: Top Renewable & Alternative Energy Trends in 2026\n\nIf you want, I can provide more detailed company info or trends.', type='output_text', logprobs=[])], role='assistant', status='completed', type='message')], parallel_tool_calls=True, temperature=1.0, tool_choice='auto', tools=[WebSearchTool(type='web_search', filters=None, search_context_size='medium', user_location=UserLocation(city=None, country='US', region=None, timezone=None, type='approximate'))], top_p=1.0, background=False, conversation=None, max_output_tokens=None, max_tool_calls=None, previous_response_id=None, prompt=None, prompt_cache_key=None, reasoning=Reasoning(effort=None, generate_summary=None, summary=None), safety_identifier=None, service_tier='default', status='completed', text=ResponseTextConfig(format=ResponseFormatText(type='text'), verbosity='medium'), top_logprobs=0, truncation='disabled', usage=ResponseUsage(input_tokens=6108, input_tokens_details=InputTokensDetails(cached_tokens=0), output_tokens=498, output_t ...

# %% [markdown]
# ### Location-aware lookup
# Optionally bias results by providing an approximate country code.

# %%
# Demonstrate location-biased search results via user_location.
location_tools = [
    {
        "type": "web_search",
        "user_location": {"type": "approximate", "country": country or "US"},
    }
]

run_search(
    "Share a positive news story from the web today.",
    tools=location_tools,
)
# Out:
# Here is a positive news story from today:
#
# An Indian teacher named Rouble Nagi has won the $1 million Global Teacher Prize from GEMS Education for her incredible work of establishing more than 800 learning centers across India. These centers offer education to children in slums and villages who have never attended school, providing safe and inspiring spaces despite the challenges of poverty, child labor, and lack of infrastructure. Her efforts have created many educational opportunities and hope for disadvantaged children in India.
#
# You can read more about her inspiring story here: [Good News Network - Teacher wins $1M prize for turning India's slums into hundreds of open-air classrooms](https://www.sunnyskyz.com/good-news)
#
# ================================================================================
# Citations:
# ================================================================================
#
# [1] [Good News Network - Teacher wins $1M prize for turning India's slums into hundreds of open-air classrooms](https://www.sunnyskyz.com/good-news)
#     URL: https://www.sunnyskyz.com/good-news
#     Title: Good News Stories - Sunny Skyz
# ================================================================================
#
# ================================================================================
# Tool calls:
# ================================================================================
#
# Call 1:
# {
#   "id": "ws_0b40a05e44a37f9f0069ae4beebc3481958311170fee8017df",
#   "action": {
#     "query": "positive news story March 9, 2026",
#     "type": "search",
#     "sources": null,
#     "queries": [
#       "positive news story March 9, 2026"
#     ]
#   },
#   "status": "searching",
#   "type": "web_search_call"
# }
# ================================================================================
# Response(id='resp_0b40a05e44a37f9f0069ae4bee7968819582cba619acdb8961', created_at=1773030382.0, error=None, incomplete_details=None, instructions=None, metadata={}, model='gpt-4.1-mini', object='response', output=[ResponseFunctionWebSearch(id='ws_0b40a05e44a37f9f0069ae4beebc3481958311170fee8017df', action=ActionSearch(query='positive news story March 9, 2026', type='search', sources=None, queries=['positive news story March 9, 2026']), status='searching', type='web_search_call'), ResponseOutputMessage(id='msg_0b40a05e44a37f9f0069ae4bef82988195aee188fdbfc44e05', content=[ResponseOutputText(annotations=[AnnotationURLCitation(end_index=733, start_index=589, title='Good News Stories - Sunny Skyz', type='url_citation', url='https://www.sunnyskyz.com/good-news')], text="Here is a positive news story from today:\n\nAn Indian teacher named Rouble Nagi has won the $1 million Global Teacher Prize from GEMS Education for her incredible work of establishing more than 800 learning centers across India. These centers offer education to children in slums and villages who have never attended school, providing safe and inspiring spaces despite the challenges of poverty, child labor, and lack of infrastructure. Her efforts have created many educational opportunities and hope for disadvantaged children in India.\n\nYou can read more about her inspiring story here: [Good News Network - Teacher wins $1M prize for turning India's slums into hundreds of open-air classrooms](https://www.sunnyskyz.com/good-news)", type='output_text', logprobs=[])], role='assistant', status='completed', type='message')], parallel_tool_calls=True, temperature=1.0, tool_choice='auto', tools=[WebSearchTool(type='web_search', filters=None, search_context_size='medium', user_location=UserLocation(city=None, country='US', region=None, timezone=None, type='approximate'))], top_p=1.0, background=False, conversation=None, max_output_tokens=None, max_tool_calls=None, previous_response_id=None, prompt=None, prompt_cache_key=None, reasoning=Reasoning(effort=None, generate_summary=None, summary=None), safety_identifier=None, service_tier='default', status='completed', text=ResponseTextConfig(format=ResponseFormatText(type='text'), verbosity='medium'), top_logprobs=0, truncation='disabled', usage=ResponseUsage(input_tokens=6732, input_tokens_details=InputTokensDetails(cached_tokens=0), output_tokens=165, output_tokens_details=OutputTokensDetails(reasoning_tokens=0), total_tokens=6897), user=None, completed_at=1773030384, content_filters=[{'blocked': False, 'source_type': 'prompt', 'content_filter_raw': [], 'content_filter_results': {'indirect_attack': {'detected': False, 'filtered': False}, 'hate': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'jailbreak': {'detected': False, 'filtered': False}}, 'content_filter_offsets': {'start_offset': 0, 'end_offset': 80, 'check_offset': 0}}, {'blocked': False, 'source_type': 'completion', 'content_filter_raw': [], 'content_filter_results': {'protected_material_code': {'detected': False, 'filtered': False}, 'protected_material_text': {'detected': False, 'filtered': False}, 'hate': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'low'}, 'self_harm': {'filtered': False, 'severity': 'safe'}}, 'content_filter_offsets': {'start_offset': 0, 'end_offset': 28698, 'check_offset': 0}}], frequency_penalty=0.0, presence_penalty=0.0, prompt_cache_retention=None, store=True)

# %% [markdown]
# ### Deep research (multi-step)
# Includes the `code_interpreter` tool to let the model perform extended reasoning. Requires a deployment that supports `o3-deep-research`.

# %%
# Optionally use a deep research model if configured in the environment.
print(deep_model)

if deep_model:
    run_search(
        "Research What are the top 5 renewable energy trends in 2026, and which companies are leading in solar and wind adoption globally?",
        tools=[
            {"type": "web_search"},
            #{"type": "code_interpreter", "container": {"type": "auto"}},
        ],
        model_override=deep_model,
    )
else:
    print("Skip deep research demo; set AZURE_OPENAI_DEEP_MODEL to enable.")
# Out:
# o3-pro
# Top 5 renewable-energy trends to watch in 2026
#
# 1. Long-duration energy storage goes mainstream
#    • Prices for next-generation lithium-silicon, sodium-ion and flow batteries continue to fall, and more than 30 GW of stand-alone or co-located storage is expected to be commissioned worldwide in 2026. Utilities and developers are pairing solar and wind with four-hour-plus batteries to supply “clean-firm” power and to qualify for capacity and grid-services revenues.
#
# 2. Green hydrogen moves from pilots to first-wave commercial hubs
#    • Policy clarity in the EU’s Delegated Acts and multigigawatt auctions in India and the Middle East are triggering final-investment decisions for 100 MW-scale electrolyser projects. Electrolyser costs have dropped below US $500 per kW, opening a viable pathway to decarbonise steel, fertiliser and heavy transport.
#
# 3. Offshore—and now floating—wind scales rapidly
#    • Fixed-bottom additions in China, the North Sea and the U.S. Atlantic will lift global offshore wind capacity past 100 GW in 2026, while the first 200-MW-class floating arrays off Portugal and South Korea prove commercial bankability. Hybrid “wind-plus-hydrogen” platforms are entering early construction.
#
# 4. High-efficiency solar: perovskites, tandems and BIPV
#    • Commercial perovskite-silicon tandem modules exceeding 28 % efficiency start shipping from lines in China and Europe; building-integrated PV (BIPV) and floating-solar demand soars in land-constrained markets, pushing global PV installations toward 400 GW in 2026.
#
# 5. AI-driven smart grids and virtual power plants (VPPs)
#    • Surging data-centre electricity demand is straining grids; operators are responding with AI-optimised demand response, distributed batteries and aggregated DER/VPP platforms that can provide ancillary services in minutes. 24 / 7 carbon-free-energy procurement models pioneered by big tech accelerate this digitalisation push.
#
# ————————————————————————
# 2026 leaders in solar and wind adoption (utility-scale ownership or corporate offtake)
#
# A. Solar power (utility-scale PV ownership, end-2025 capacities)
# 1. State Power Investment Corporation (SPIC, China) – ≈ 16.4 GWac of utility-scale PV, the world’s largest owner.
# 2. NextEra Energy Resources (USA) – ≈ 12.4 GWac; continues to dominate North American solar growth.
# 3. Enel Green Power (Italy/global) – ≈ 11.7 GWac across five continents.
# 4. ENGIE (France/global) – ≈ 11.1 GWac of PV in operation after a record 2024 build-out.
# 5. Adani Green Energy (India) – ≈ 7 GWac, the fastest-growing solar owner in Asia.
#
# B. Wind power (leading developers/operators)
# 1. Ørsted (Denmark) – ~18 GW total wind capacity, including 10.2 GW of operating offshore wind—the largest global offshore portfolio.
# 2. NextEra Energy Resources (USA) – operates 126 wind projects, making it the world’s largest wind-and-solar operator by project count and total output.
# 3. RWE (Germany/global) – > 19 GW of wind (≈ 3.3 GW offshore, 15 + GW onshore) after rapid 2024-25 expansion.
# 4. Iberdrola/Avangrid (Spain/USA) – ≈ 2.4 GW offshore and a double-digit-GW onshore fleet, cementing its place among the top five global wind owners.
# 5. China Three Gorges Corporation (CTG, China) – major on- and offshore wind investor; in the global top-10 offshore developers with multi-GW pipeline and operating fleet.
#
# Corporate renewable buyers
# • Amazon remains the largest corporate purchaser of solar and wind for the fifth straight year, with >600 projects totaling over 100 GW of contracted clean energy—enough to power ~8 million U.S. homes.
#
# These companies and technology trends define the front line of renewable-energy deployment as 2026 begins, setting the pace for the sector’s growth through the rest of the decade.
#
# ================================================================================
# Citations:
# ================================================================================
#
# [1] a) – major on- and offshore wind investor; in the global top-10 offshore developers with multi-GW pipeline and operating fleet.
#
# Corporate renewable buyers
# • Amazon remains the largest corporate purchaser of solar and wind for the fifth straight yea
#     URL: https://www.rwe.com/-/media/RWE/documents/05-investor-relations/finanzkalendar-und-veroeffentlichungen/2025-Q3/25-10-23-rwe-q1-q3-2025-pre-release-capacity-and-power-generation-data.pdf
#     Title: Q1-Q3 2025 installed capacity and power generation data - rwe.com
#
# [2]
#     URL: https://wwindea.org/ss-uploads/media/2025/11/1762774319-1833f696-4ee8-43ce-95c2-9c8c48f43790.pdf
#     Title: WWEA Half-year Report 2025 - wwindea.org
#
# [3]
#     URL: https://windinsider.com/2025/08/16/rwe-posts-e2-1-billion-adjusted-ebitda-in-first-half-of-2025-on-track-to-meet-full-year-targets/
#     Title: RWE Posts €2.1 Billion Adjusted EBITDA in First Half of 2025, On Track ...
# ================================================================================
#
# ================================================================================
# Tool calls:
# ================================================================================
#
# Call 1:
# {
#   "id": "ws_0ef2f6232832356b0069686ed858b881958bb228d5bc1ca864",
#   "action": {
#     "query": "2026 renewable energy trends top 5 2026 green hydrogen energy storage virtual power plants corporate PPA",
#     "type": "search",
#     "sources": null
#   },
#   "status": "completed",
#   "type": "web_search_call"
# }
#
# Call 2:
# {
#   "id": "ws_0ef2f6232832356b0069686ed8726c8195b6e4bf4911a0567a",
#   "action": {
#     "query": "largest solar power plant operators 2025 worldwide installed capacity",
#     "type": "search",
#     "sources": null
#   },
#   "status": "completed",
#   "type": "web_search_call"
# }
#
# Call 3:
# {
#   "id": "ws_0ef2f6232832356b0069686ed886bc8195ac94edaf8781b608",
#   "action": {
#     "query": "top renewable energy trends 2026 green hydrogen, energy storage 2026",
#     "type": "search",
#     "sources": null
#   },
#   "status": "completed",
#   "type": "web_search_call"
# }
#
# Call 4:
# {
#   "id": "ws_0ef2f6232832356b0069686ed89a2481959f19a03e02c60173",
#   "action": {
#     "query": "largest corporate renewable energy purchasers 2025 amazon google",
#     "type": "search",
#     "sources": null
#   },
#   "status": "completed",
#   "type": "web_search_call"
# }
#
# Call 5:
# {
#   "id": "ws_0ef2f6232832356b0069686ed8a8748195b874bfa0d243c6bb",
#   "action": {
#     "query": "2025 top corporate renewable energy buyers 2025 report CEBA",
#     "type": "search",
#     "sources": null
#   },
#   "status": "completed",
#   "type": "web_search_call"
# }
#
# Call 6:
# {
#   "id": "ws_0ef2f6232832356b0069686ed8b0a48195a08412dacb25dd04",
#   "action": {
#     "query": "largest wind power operators 2025 company installed capacity ranking",
#     "type": "search",
#     "sources": null
#   },
#   "status": "completed",
#   "type": "web_search_call"
# }
#
# Call 7:
# {
#   "id": "ws_0ef2f6232832356b0069686ed8b8488195b7725f3f9522628f",
#   "action": {
#     "query": "largest wind power asset owners 2025 global",
#     "type": "search",
#     "sources": null
#   },
#   "status": "completed",
#   "type": "web_search_call"
# }
#
# Call 8:
# {
#   "id": "ws_0ef2f6232832356b0069686ed8c7d881959fa54731f50b56a3",
#   "action": {
#     "query": "top wind power asset owners 2025 next era energy orsted state power investment",
#     "type": "search",
#     "sources": null
#   },
#   "status": "completed",
#   "type": "web_search_call"
# }
#
# Call 9:
# {
#   "id": "ws_0ef2f6232832356b0069686ed8d5888195b244625586d5b26f",
#   "action": {
#     "query": "top wind asset owners 2025 ranking",
#     "type": "search",
#     "sources": null
#   },
#   "status": "completed",
#   "type": "web_search_call"
# }
#
# Call 10:
# {
#   "id": "ws_0ef2f6232832356b0069686ed8e25481959f995b7b79e5467a",
#   "action": {
#     "query": "largest wind power company by installed capacity 2025",
#     "type": "search",
#     "sources": null
#   },
#   "status": "completed",
#   "type": "web_search_call"
# }
#
# Call 11:
# {
#   "id": "ws_0ef2f6232832356b0069686ed8ed748195b55d944e94c13996",
#   "action": {
#     "query": "NextEra Energy total wind capacity 2025",
#     "type": "search",
#     "sources": null
#   },
#   "status": "completed",
#   "type": "web_search_call"
# }
#
# Call 12:
# {
#   "id": "ws_0ef2f6232832356b0069686ed903f4819595b71f89436b3fa3",
#   "action": {
#     "query": "NextEra Energy wind capacity 22 GW 2025",
#     "type": "search",
#     "sources": null
#   },
#   "status": "completed",
#   "type": "web_search_call"
# }
#
# Call 13:
# {
#   "id": "ws_0ef2f6232832356b0069686ed9187c81959f89e1fba6669f80",
#   "action": {
#     "query": "RWE total wind capacity 2025",
#     "type": "search",
#     "sources": null
#   },
#   "status": "completed",
#   "type": "web_search_call"
# }
# ================================================================================

# %% [markdown]
# ### Domain filtering
# Limit web search results to specific domains using the `filters` parameter with an allow-list of up to 100 URLs. When formatting URLs, omit the HTTP/HTTPS prefix (use `openai.com` instead of `https://openai.com/`). This includes subdomains in the search.
#
# The `sources` field returns the complete list of URLs consulted, which is often greater than inline citations. Real-time feeds are labeled as `oai-sports`, `oai-weather`, or `oai-finance`.

# %%
# Restrict sources to trusted medical domains and review sources returned.
filtered_tools = [
    {
        "type": "web_search",
        "filters": {
            "allowed_domains": [
                "pubmed.ncbi.nlm.nih.gov",
                "clinicaltrials.gov",
                "www.who.int",
                "www.cdc.gov",
                "www.fda.gov"
            ]
        }
    }
]

response = run_search(
    "Please perform a web search on how semaglutide is used in the treatment of diabetes.",
    tools=filtered_tools,
)

# Display sources if available to validate domain filtering.
if hasattr(response, 'output') and response.output:
    sources = []
    for item in response.output:
        if hasattr(item, 'sources') and item.sources:
            sources.extend(item.sources)
    
    if sources:
        print("\n" + "=" * 80)
        print(f"Sources consulted ({len(sources)} total):")
        print("=" * 80)
        for i, source in enumerate(sources, 1):
            print(f"{i}. {source}")
        print("=" * 80)
# Out:
# ### What semaglutide is (and why it’s used for diabetes)
# - **Semaglutide** is a **GLP-1 receptor agonist**. It **mimics the GLP‑1 hormone** released after eating, which **increases insulin release**, **lowers blood glucose**, and can also **reduce appetite**. ([fda.gov](https://www.fda.gov/drugs/postmarket-drug-safety-information-patients-and-providers/medications-containing-semaglutide-marketed-type-2-diabetes-or-weight-loss?os=...&ref=app))
# - In the U.S., semaglutide products approved for **type 2 diabetes** are:
#   - **Ozempic** (injection) and **Rybelsus** (tablet): approved to **improve/lower blood sugar in adults with type 2 diabetes**, used **with diet and exercise**. ([fda.gov](https://www.fda.gov/drugs/postmarket-drug-safety-information-patients-and-providers/medications-containing-semaglutide-marketed-type-2-diabetes-or-weight-loss?os=...&ref=app))
#   - **Ozempic** also has an approval to **reduce risk of major cardiovascular events** (heart attack, stroke, or death) in adults with **type 2 diabetes + known heart disease**. ([fda.gov](https://www.fda.gov/drugs/postmarket-drug-safety-information-patients-and-providers/medications-containing-semaglutide-marketed-type-2-diabetes-or-weight-loss?os=...&ref=app))
#
# ### How semaglutide is used in treatment (per FDA/CDC sources)
# - **As an add-on to lifestyle measures:** FDA describes Ozempic as improving blood sugar control in adults with type 2 diabetes **in addition to diet and exercise**. ([fda.gov](https://www.fda.gov/drugs/drug-approvals-and-databases/drug-trial-snapshot-Ozempic))
# - **Once-weekly injection option (Ozempic):** Ozempic is given **subcutaneously once weekly** (abdomen, thigh, or upper arm). ([fda.gov](https://www.fda.gov/drugs/drug-approvals-and-databases/drug-trial-snapshot-Ozempic))
# - **Alone or with other diabetes medicines:** FDA notes Ozempic **may be used alone** or **with other FDA-approved diabetes medications** (examples listed include metformin and insulin; if used with insulin, inject separately and don’t mix). ([fda.gov](https://www.fda.gov/drugs/drug-approvals-and-databases/drug-trial-snapshot-Ozempic))
# - **Why it’s often chosen (beyond glucose):** CDC summarizes that GLP‑1 medicines (the class that includes semaglutide) **lower blood sugar**, can help with **weight loss**, and **protect the heart and kidneys**; GLP‑1s can also be used **together with SGLT‑2 inhibitors** because they work differently. ([cdc.gov](https://www.cdc.gov/diabetes/data-research/research/new-diabetes-medicines.html))
#
# ### Guideline context / who may be prioritized
# - CDC highlights that recent ADA/EASD guidance emphasizes GLP‑1 medicines for many adults with type 2 diabetes—especially those with **atherosclerotic cardiovascular disease (ASCVD)**, **heart failure**, **kidney disease**, or **high ASCVD risk**. ([cdc.gov](https://www.cdc.gov/diabetes/data-research/research/new-diabetes-medicines.html))
# - WHO reported in **September 2025** that updated WHO essential medicines lists include diabetes treatments (noting access and pricing issues for medicines like semaglutide). ([who.int](https://www.who.int/news/item/05-09-2025-who-updates-list-of-essential-medicines-to-include-key-cancer--diabetes-treatments))
#
# ### Safety/regulatory note (important in real-world use)
# - FDA warns there are concerns about **compounded semaglutide** (not FDA-approved for safety/effectiveness/quality) and reports of adverse events; FDA also notes issues with some compounders using **salt forms** (e.g., semaglutide sodium/acetate) rather than the base form used in approved products. ([fda.gov](https://www.fda.gov/drugs/postmarket-drug-safety-information-patients-and-providers/medications-containing-semaglutide-marketed-type-2-diabetes-or-weight-loss?os=...&ref=app))
#
# If you tell me whether you mean **Ozempic (weekly injection)** or **Rybelsus (daily tablet)**, I can summarize the typical “where it fits” in type 2 diabetes therapy (e.g., before/after insulin, in people with ASCVD/CKD, etc.) using only CDC/FDA/WHO/PubMed sources.
#
# ================================================================================
# Citations:
# ================================================================================
#
# [1] ([fda.gov](https://www.fda.gov/drugs/postmarket-drug-safety-information-patients-and-providers/medications-containing-semaglutide-marketed-type-2-diabetes-or-weight-loss?os=...&ref=app))
#     URL: https://www.fda.gov/drugs/postmarket-drug-safety-information-patients-and-providers/medications-containing-semaglutide-marketed-type-2-diabetes-or-weight-loss?os=...&ref=app
#     Title: Medications Containing Semaglutide Marketed for Type 2 Diabetes or ...
#
# [2] ([fda.gov](https://www.fda.gov/drugs/postmarket-drug-safety-information-patients-and-providers/medications-containing-semaglutide-marketed-type-2-diabetes-or-weight-loss?os=...&ref=app))
#     URL: https://www.fda.gov/drugs/postmarket-drug-safety-information-patients-and-providers/medications-containing-semaglutide-marketed-type-2-diabetes-or-weight-loss?os=...&ref=app
#     Title: Medications Containing Semaglutide Marketed for Type 2 Diabetes or ...
#
# [3] ([fda.gov](https://www.fda.gov/drugs/postmarket-drug-safety-information-patients-and-providers/medications-containing-semaglutide-marketed-type-2-diabetes-or-weight-loss?os=...&ref=app))
#     URL: https://www.fda.gov/drugs/postmarket-drug-safety-information-patients-and-providers/medications-containing-semaglutide-marketed-type-2-diabetes-or-weight-loss?os=...&ref=app
#     Title: Medications Containing Semaglutide Marketed for Type 2 Diabetes or ...
#
# [4] ([fda.gov](https://www.fda.gov/drugs/drug-approvals-and-databases/drug-trial-snapshot-Ozempic))
#     URL: https://www.fda.gov/drugs/drug-approvals-and-databases/drug-trial-snapshot-Ozempic
#     Title: Ozempic Drug Trial Snapshot - FDA
#
# [5] ([fda.gov](https://www.fda.gov/drugs/drug-approvals-and-databases/drug-trial-snapshot-Ozempic))
#     URL: https://www.fda.gov/drugs/drug-approvals-and-databases/drug-trial-snapshot-Ozempic
#     Title: Ozempic Drug Trial Snapshot - FDA
#
# [6] ([fda.gov](https://www.fda.gov/drugs/drug-approvals-and-databases/drug-trial-snapshot-Ozempic))
#     URL: https://www.fda.gov/drugs/drug-approvals-and-databases/drug-trial-snapshot-Ozempic
#     Title: Ozempic Drug Trial Snapshot - FDA
#
# [7] ([cdc.gov](https://www.cdc.gov/diabetes/data-research/research/new-diabetes-medicines.html))
#     URL: https://www.cdc.gov/diabetes/data-research/research/new-diabetes-medicines.html
#     Title: Use of New Diabetes Medicines | Diabetes | CDC
#
# [8] ([cdc.gov](https://www.cdc.gov/diabetes/data-research/research/new-diabetes-medicines.html))
#     URL: https://www.cdc.gov/diabetes/data-research/research/new-diabetes-medicines.html
#     Title: Use of New Diabetes Medicines | Diabetes | CDC
#
# [9] ([who.int](https://www.who.int/news/item/05-09-2025-who-updates-list-of-essential-medicines-to-include-key-cancer--diabetes-treatments))
#     URL: https://www.who.int/news/item/05-09-2025-who-updates-list-of-essential-medicines-to-include-key-cancer--diabetes-treatments
#     Title: WHO updates list of essential medicines to include key cancer, diabetes ...
#
# [10] ([fda.gov](https://www.fda.gov/drugs/postmarket-drug-safety-information-patients-and-providers/medications-containing-semaglutide-marketed-type-2-diabetes-or-weight-loss?os=...&ref=app))
#     URL: https://www.fda.gov/drugs/postmarket-drug-safety-information-patients-and-providers/medications-containing-semaglutide-marketed-type-2-diabetes-or-weight-loss?os=...&ref=app
#     Title: Medications Containing Semaglutide Marketed for Type 2 Diabetes or ...
# ================================================================================
#
# ================================================================================
# Tool calls:
# ================================================================================
#
# Call 1:
# {
#   "id": "ws_0ff1dcb9bd5ba02f0069ae4c2c645c8194949fd9d70ae4e298",
#   "action": {
#     "query": "CDC semaglutide type 2 diabetes GLP-1 receptor agonist",
#     "type": "search",
#     "sources": null,
#     "queries": [
#       "CDC semaglutide type 2 diabetes GLP-1 receptor agonist",
#       "FDA label Ozempic semaglutide indication type 2 diabetes dosing",
#       "WHO semaglutide type 2 diabetes essential medicines",
#       "PubMed semaglutide type 2 diabetes trial SUSTAIN summary"
#     ]
#   },
#   "status": "completed",
#   "type": "web_search_call"
# }
#
# Call 2:
# {
#   "id": "ws_0ff1dcb9bd5ba02f0069ae4c31d0ac8194bd24f5abe33b0710",
#   "action": {
#     "type": "open_page",
#     "url": "https://www.fda.gov/drugs/drug-approvals-and-databases/drug-trial-snapshot-Ozempic"
#   },
#   "status": "completed",
#   "type": "web_search_call"
# }
# ================================================================================

# %%
# March Madness 2026 tournament search with sports domain filtering.

filtered_tools = [
    {
        "type": "web_search",
        "filters": {
            "allowed_domains": [
                "www.ncaa.com",
                "www.espn.com",
                "www.cbssports.com",
                "bleacherreport.com",
                "www.sports-reference.com"
            ]
        }
    }
]

response = run_search(
    "Please perform a web search for the 2026 NCAA March Madness tournament bracket, schedule, and results.",
    tools=filtered_tools,
)

# Display sources if available to validate domain filtering.
if hasattr(response, 'output') and response.output:
    sources = []
    for item in response.output:
        if hasattr(item, 'sources') and item.sources:
            sources.extend(item.sources)

    if sources:
        print("\n" + "=" * 80)
        print(f"Sources consulted ({len(sources)} total):")
        print("=" * 80)
        for i, source in enumerate(sources, 1):
            print(f"{i}. {source}")
        print("=" * 80)
# Out:
# Here are web-search sources (limited to NCAA.com, ESPN, CBS Sports, Bleacher Report, and Sports-Reference) for the **2026 NCAA Men’s March Madness bracket, schedule, and results**:
#
# ## Bracket (interactive / printable)
# - **Official NCAA.com printable bracket + schedule** ([ncaa.com](https://www.ncaa.com/news/basketball-men/mml-official-bracket/2026-01-28/2026-ncaa-tournament-printable-bracket-schedule-march-madness))
# - **CBS Sports interactive bracket (real-time scores as games are played)** ([cbssports.com](https://www.cbssports.com/college-basketball/ncaa-tournament/bracket/))
# - **CBS Sports printable bracket** ([cbssports.com](https://www.cbssports.com/college-basketball/ncaa-tournament/bracket/printable-men/))
#
# ## Schedule (dates, sites, locations)
# - **NCAA.com: 2026 tournament schedule & dates** ([ncaa.com](https://www.ncaa.com/news/basketball-men/article/2025-06-12/2026-march-madness-mens-ncaa-tournament-schedule-dates))
# - **ESPN: schedule, sites, locations overview** ([espn.com](https://www.espn.com/mens-college-basketball/story/_/id/46583333/mens-college-basketball-march-madness-2026-schedule-sites-locations-selection-sunday))
# - **NCAA.com: Selection Sunday date + TV times** ([ncaa.com](https://www.ncaa.com/news/basketball-men/article/2026-03-04/2026-selection-sunday-date-schedule-tv-times-march-madness))
#
# Key dates shown on NCAA.com:
# - **Selection Sunday:** March 15, 2026
# - **First Four:** March 17–18, 2026
# - **First Round:** March 19–20, 2026
# - **Second Round:** March 21–22, 2026
# - **Sweet 16:** March 26–27, 2026
# - **Elite Eight:** March 28–29, 2026
# - **Final Four:** April 4, 2026
# - **Championship:** April 6, 2026 ([ncaa.com](https://www.ncaa.com/news/basketball-men/article/2025-06-12/2026-march-madness-mens-ncaa-tournament-schedule-dates))
#
# ## Results (as games are played / tournament summary)
# - **CBS Sports bracket page for live scores/results as the tournament progresses** ([cbssports.com](https://www.cbssports.com/college-basketball/ncaa-tournament/bracket/))
# - **Sports-Reference: 2026 Men’s NCAA Tournament Summary (results/summary page)** ([sports-reference.com](https://www.sports-reference.com/cbb/postseason/men/2026-ncaa.html))
#
# If you tell me whether you want **men’s** only (the links above) or also **women’s**, I can pull the corresponding women’s bracket/schedule pages from the same allowed sites.
#
# ================================================================================
# Citations:
# ================================================================================
#
# [1] ([ncaa.com](https://www.ncaa.com/news/basketball-men/mml-official-bracket/2026-01-28/2026-ncaa-tournament-printable-bracket-schedule-march-madness))
#     URL: https://www.ncaa.com/news/basketball-men/mml-official-bracket/2026-01-28/2026-ncaa-tournament-printable-bracket-schedule-march-madness
#     Title: 2026 NCAA tournament printable bracket, schedule for March Madness
#
# [2] ([cbssports.com](https://www.cbssports.com/college-basketball/ncaa-tournament/bracket/))
#     URL: https://www.cbssports.com/college-basketball/ncaa-tournament/bracket/
#     Title: March Madness Bracket - 2026 NCAA Basketball Tournament
#
# [3] ([cbssports.com](https://www.cbssports.com/college-basketball/ncaa-tournament/bracket/printable-men/))
#     URL: https://www.cbssports.com/college-basketball/ncaa-tournament/bracket/printable-men/
#     Title: Printable March Madness Bracket - 2026 NCAA Tournament
#
# [4] ([ncaa.com](https://www.ncaa.com/news/basketball-men/article/2025-06-12/2026-march-madness-mens-ncaa-tournament-schedule-dates))
#     URL: https://www.ncaa.com/news/basketball-men/article/2025-06-12/2026-march-madness-mens-ncaa-tournament-schedule-dates
#     Title: 2026 March Madness: Men's NCAA tournament schedule, dates
#
# [5] ([espn.com](https://www.espn.com/mens-college-basketball/story/_/id/46583333/mens-college-basketball-march-madness-2026-schedule-sites-locations-selection-sunday))
#     URL: https://www.espn.com/mens-college-basketball/story/_/id/46583333/mens-college-basketball-march-madness-2026-schedule-sites-locations-selection-sunday
#     Title: Men's March Madness 2026 schedule, sites, locations - ESPN
#
# [6] ([ncaa.com](https://www.ncaa.com/news/basketball-men/article/2026-03-04/2026-selection-sunday-date-schedule-tv-times-march-madness))
#     URL: https://www.ncaa.com/news/basketball-men/article/2026-03-04/2026-selection-sunday-date-schedule-tv-times-march-madness
#     Title: 2026 Selection Sunday: Date, schedule, TV times for March Madness
#
# [7] ([ncaa.com](https://www.ncaa.com/news/basketball-men/article/2025-06-12/2026-march-madness-mens-ncaa-tournament-schedule-dates))
#     URL: https://www.ncaa.com/news/basketball-men/article/2025-06-12/2026-march-madness-mens-ncaa-tournament-schedule-dates
#     Title: 2026 March Madness: Men's NCAA tournament schedule, dates
#
# [8] ([cbssports.com](https://www.cbssports.com/college-basketball/ncaa-tournament/bracket/))
#     URL: https://www.cbssports.com/college-basketball/ncaa-tournament/bracket/
#     Title: March Madness Bracket - 2026 NCAA Basketball Tournament
#
# [9] ([sports-reference.com](https://www.sports-reference.com/cbb/postseason/men/2026-ncaa.html))
#     URL: https://www.sports-reference.com/cbb/postseason/men/2026-ncaa.html
#     Title: 2026 Men's NCAA Tournament Summary - Sports-Reference.com
# ================================================================================
#
# ================================================================================
# Tool calls:
# ================================================================================
#
# Call 1:
# {
#   "id": "ws_03fef37e1880e7420069aedd999734819492fa1cd2537b7832",
#   "action": {
#     "query": "2026 NCAA March Madness bracket schedule results",
#     "type": "search",
#     "sources": null,
#     "queries": [
#       "2026 NCAA March Madness bracket schedule results"
#     ]
#   },
#   "status": "completed",
#   "type": "web_search_call"
# }
# ================================================================================

# %%
# Placeholder cell for additional experiments or notes.
