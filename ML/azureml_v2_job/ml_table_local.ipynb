# %%
import time
from azure.ai.ml import MLClient
from azure.ai.ml.entities import Data
from azure.ai.ml.constants import AssetTypes
from azure.identity import DefaultAzureCredential
from dotenv import load_dotenv

load_dotenv()

# set the version number of the data asset to the current UTC time
VERSION = time.strftime("%Y.%m.%d.%H%M%S", time.gmtime())

# connect to the AzureML workspace
# NOTE: subscription_id, resource_group, workspace were set in a previous snippet.
ml_client = MLClient.from_config(credential=DefaultAzureCredential(),)

my_data = Data(
    path="../data/jsonl",
    type=AssetTypes.MLTABLE,
    description="MLTable data asset example",
    name="jsonl-data-asset",
    version=VERSION,
)

ml_client.data.create_or_update(my_data)
# Out:
# Found the config file in: .\config.json
# Overriding of current MeterProvider is not allowed
# Overriding of current TracerProvider is not allowed
# Overriding of current LoggerProvider is not allowed
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File c:\Users\jacwang\AppData\Local\anaconda3\envs\finagent\Lib\site-packages\azure\ai\ml\_utils\utils.py:313, in load_yaml(source)
#     312 try:
# --> 313     cm = open(source, "r", encoding=DefaultOpenEncoding.READ)
#     314 except OSError as e:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\repo\\ai-foundry-craftkit\\ML\\data\\MLTable'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
import mltable
from azure.ai.ml import MLClient
from azure.identity import DefaultAzureCredential


# get the latest version of the data asset
# Note: the variable VERSION is set in the previous code
data_asset = ml_client.data.get(name="jsonl-data-asset", version=VERSION)

# the table from the data asset id
tbl = mltable.load(f"azureml:/{data_asset.id}")

# load into pandas
df = tbl.to_pandas_dataframe()
df.head()
# Out:
# Overriding of current MeterProvider is not allowed
# Overriding of current TracerProvider is not allowed
# Overriding of current LoggerProvider is not allowed
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# c:\Users\jacwang\AppData\Local\anaconda3\envs\finagent\Lib\site-packages\azureml\dataprep\api\_dataframereader.py:251: UserWarning: Using alternate reader. Inconsistent or mixed schemas detected across partitions: partition had different number of columns. The first partition has 3 columns. Found partition has 4 columns.
# First partition columns (ordered): ['id', 'text', 'label']
# Found Partition has columns (ordered): ['id', 'title', 'priority', 'tags']
#   warnings.warn("Using alternate reader. " + reason)
#    id                         text    label             title priority  \
# 0   1  How do I reset my password?  support              None     None
# ...

# %%
import mltable
from azure.ai.ml import MLClient
from azure.identity import DefaultAzureCredential


# get the latest version of the data asset
# Note: the variable VERSION is set in the previous code
data_asset = ml_client.data.get(name="jsonl-data-asset", version=VERSION)

# the table from the data asset id
tbl = mltable.load(f"azureml:/{data_asset.id}")

# load into pandas
df = tbl.to_pandas_dataframe()
df.head()
# Out:
# Overriding of current MeterProvider is not allowed
# Overriding of current TracerProvider is not allowed
# Overriding of current LoggerProvider is not allowed
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# c:\Users\jacwang\AppData\Local\anaconda3\envs\finagent\Lib\site-packages\azureml\dataprep\api\_dataframereader.py:251: UserWarning: Using alternate reader. Inconsistent or mixed schemas detected across partitions: partition had different number of columns. The first partition has 3 columns. Found partition has 4 columns.
# First partition columns (ordered): ['id', 'text', 'label']
# Found Partition has columns (ordered): ['id', 'title', 'priority', 'tags']
#   warnings.warn("Using alternate reader. " + reason)
#    id                         text    label             title priority  \
# 0   1  How do I reset my password?  support              None     None
# ...

# %%
#Help me generate the MLTable
