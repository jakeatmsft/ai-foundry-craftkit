# %% [markdown]
# # Azure ML v2 Job Submission
#
# This notebook submits a command job that reads JSONL data from the `../data` MLTable and runs the script in `./src`.

# %%
from dotenv import load_dotenv
load_dotenv(override=True)

import os
from azure.ai.ml import MLClient
from azure.identity import DefaultAzureCredential

ml_client = MLClient.from_config(
    DefaultAzureCredential(),

)
# Out:
# Found the config file in: .\config.json
# Overriding of current MeterProvider is not allowed
# Overriding of current TracerProvider is not allowed
# Overriding of current LoggerProvider is not allowed
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented

# %%
from azure.ai.ml.entities import Environment, BuildContext

env_docker_conda = Environment(
    image="mcr.microsoft.com/azureml/curated/python-sdk-v2:42",
    conda_file="./conda.yaml",
    name="amlsdk_mltable",
    description="Environment created from a Docker image plus Conda environment.",
)
ml_client.environments.create_or_update(env_docker_conda)
# Out:
# Environment({'arm_type': 'environment_version', 'latest_version': None, 'image': 'mcr.microsoft.com/azureml/curated/python-sdk-v2:42', 'intellectual_property': None, 'is_anonymous': False, 'auto_increment_version': False, 'auto_delete_setting': None, 'name': 'amlsdk_mltable', 'description': 'Environment created from a Docker image plus Conda environment.', 'tags': {}, 'properties': {'azureml.labels': 'latest'}, 'print_as_yaml': False, 'id': '/subscriptions/6025ba02-1dfd-407f-b358-88f811c7c7aa/resourceGroups/aiagent/providers/Microsoft.MachineLearningServices/workspaces/aiml-workspace/environments/amlsdk_mltable/versions/2', 'Resource__source_path': '', 'base_path': 'c:\\repo\\ai-foundry-craftkit\\ML\\azureml_v2_job', 'creation_context': <azure.ai.ml.entities._system_data.SystemData object at 0x000002AD149C9BE0>, 'serialize': <msrest.serialization.Serializer object at 0x000002AD145B18E0>, 'version': '2', 'conda_file': {'channels': ['conda-forge', 'defaults'], 'dependencies': ['python=3.10', 'pip', {'pip': ['mltable', 'azure-ai-ml', 'azure-identity']}], 'name': 'mltable-env'}, 'build': None, 'inference_config': None, 'os_type': 'Linux', 'conda_file_path': None, 'path': None, 'datastore': None, 'upload_hash': None, 'translated_conda_file': '{\n  "channels": [\n    "conda-forge",\n    "defaults"\n  ],\n  "dependencies": [\n    "python=3.10",\n    "pip",\n    {\n      "pip": [\n        "mltable",\n        "azure-ai-ml",\n        "azure-identity"\n      ]\n    }\n  ],\n  "name": "mltable-env"\n}'})

# %%
from azure.ai.ml import Input, command
from azure.ai.ml.constants import AssetTypes

job = command(
    code="./src",
    command="python job.py",
    environment=env_docker_conda,
    compute="cpucluster",
    display_name="jsonl-mltable-demo-custom-env",
    description="Read JSONL data from MLTable and print a summary.",
)

# %%
submitted_job = ml_client.jobs.create_or_update(job)
print(f"Submitted job: {submitted_job.name}")
#ml_client.jobs.stream(submitted_job.name)
# Out:
# Warning: the provided asset name 'amlsdk_mltable' will not be used for anonymous registration
# Warning: the provided asset name 'amlsdk_mltable' will not be used for anonymous registration
# Submitted job: strong_stomach_svbbkjhbzx
